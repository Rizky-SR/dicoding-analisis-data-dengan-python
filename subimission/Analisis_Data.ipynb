# %% [markdown]
# # Proyek Analisis Data: Air Quality Dataset
# - **Nama:** Rizky Syahputra Rianto
# - **Email:** rizky.rianto2004@gmail.com
# - **ID Dicoding:** rizkysrm180d4ky1704

# %% [markdown]
# ## Menentukan Pertanyaan Bisnis

# %% [markdown]
# 1. Bagaimana perbandingan tingkat polutan total antar stasiun?
# 2. Bagaimana perbandingan tiap polutan pada tiap stasiun?
# 3. Bagaimana pengaruh kondisi lingkungan terhadap tingkat polutan?
# 4. Bagaimana fluktuasi tingkat polutan sepanjang waktu?
# 5. Bagaimana distribusi stasiun berdasarkan tingkat polutan dan kondisi lingkungan? (Cluster)

# %% [markdown]
# ## Import Semua Packages/Library yang Digunakan

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
from sklearn.preprocessing import StandardScaler
from sklearn.cluster import KMeans

# %% [markdown]
# ## Data Wrangling

# %% [markdown]
# ### Gathering Data

# %% [markdown]
# #### Load Tabel Stasiun Aotizhongxin

# %%
Aotizhongxin_df = pd.read_csv('https://raw.githubusercontent.com/Rizky-SR/dicoding-analisis-data-dengan-python/main/subimission/data/PRSA_Data_Aotizhongxin_20130301-20170228.csv')
Aotizhongxin_df.head()
# Out:
#    No  year  month  day  hour  PM2.5  PM10   SO2   NO2     CO    O3  TEMP  \
# 0   1  2013      3    1     0    4.0   4.0   4.0   7.0  300.0  77.0  -0.7
# 1   2  2013      3    1     1    8.0   8.0   4.0   7.0  300.0  77.0  -1.1
# 2   3  2013      3    1     2    7.0   7.0   5.0  10.0  300.0  73.0  -1.1
# 3   4  2013      3    1     3    6.0   6.0  11.0  11.0  300.0  72.0  -1.4
# 4   5  2013      3    1     4    3.0   3.0  12.0  12.0  300.0  72.0  -2.0
#
#      PRES  DEWP  RAIN   wd  WSPM       station
# 0  1023.0 -18.8   0.0  NNW   4.4  Aotizhongxin
# 1  1023.2 -18.2   0.0    N   4.7  Aotizhongxin
# 2  1023.5 -18.2   0.0  NNW   5.6  Aotizhongxin
# 3  1024.5 -19.4   0.0   NW   3.1  Aotizhongxin
# 4  1025.2 -19.5   0.0    N   2.0  Aotizhongxin

# %% [markdown]
# #### Load Tabel Stasiun Changping

# %%
Changping_df = pd.read_csv('https://raw.githubusercontent.com/Rizky-SR/dicoding-analisis-data-dengan-python/main/subimission/data/PRSA_Data_Changping_20130301-20170228.csv')
Changping_df.head()
# Out:
#    No  year  month  day  hour  PM2.5  PM10   SO2   NO2     CO    O3  TEMP  \
# 0   1  2013      3    1     0    3.0   6.0  13.0   7.0  300.0  85.0  -2.3
# 1   2  2013      3    1     1    3.0   3.0   6.0   6.0  300.0  85.0  -2.5
# 2   3  2013      3    1     2    3.0   3.0  22.0  13.0  400.0  74.0  -3.0
# 3   4  2013      3    1     3    3.0   6.0  12.0   8.0  300.0  81.0  -3.6
# 4   5  2013      3    1     4    3.0   3.0  14.0   8.0  300.0  81.0  -3.5
#
#      PRES  DEWP  RAIN   wd  WSPM    station
# 0  1020.8 -19.7   0.0    E   0.5  Changping
# 1  1021.3 -19.0   0.0  ENE   0.7  Changping
# 2  1021.3 -19.9   0.0  ENE   0.2  Changping
# 3  1021.8 -19.1   0.0  NNE   1.0  Changping
# 4  1022.3 -19.4   0.0    N   2.1  Changping

# %% [markdown]
# #### Load Tabel Stasiun Dingling

# %%
Dingling_df = pd.read_csv('https://raw.githubusercontent.com/Rizky-SR/dicoding-analisis-data-dengan-python/main/subimission/data/PRSA_Data_Dingling_20130301-20170228.csv')
Dingling_df.head()
# Out:
#    No  year  month  day  hour  PM2.5  PM10  SO2  NO2     CO    O3  TEMP  \
# 0   1  2013      3    1     0    4.0   4.0  3.0  NaN  200.0  82.0  -2.3
# 1   2  2013      3    1     1    7.0   7.0  3.0  NaN  200.0  80.0  -2.5
# 2   3  2013      3    1     2    5.0   5.0  3.0  2.0  200.0  79.0  -3.0
# 3   4  2013      3    1     3    6.0   6.0  3.0  NaN  200.0  79.0  -3.6
# 4   5  2013      3    1     4    5.0   5.0  3.0  NaN  200.0  81.0  -3.5
#
#      PRES  DEWP  RAIN   wd  WSPM   station
# 0  1020.8 -19.7   0.0    E   0.5  Dingling
# 1  1021.3 -19.0   0.0  ENE   0.7  Dingling
# 2  1021.3 -19.9   0.0  ENE   0.2  Dingling
# 3  1021.8 -19.1   0.0  NNE   1.0  Dingling
# 4  1022.3 -19.4   0.0    N   2.1  Dingling

# %% [markdown]
# #### Load Tabel Stasiun Dongsi

# %%
Dongsi_df = pd.read_csv('https://raw.githubusercontent.com/Rizky-SR/dicoding-analisis-data-dengan-python/main/subimission/data/PRSA_Data_Dongsi_20130301-20170228.csv')
Dongsi_df.head()
# Out:
#    No  year  month  day  hour  PM2.5  PM10  SO2   NO2     CO    O3  TEMP  \
# 0   1  2013      3    1     0    9.0   9.0  3.0  17.0  300.0  89.0  -0.5
# 1   2  2013      3    1     1    4.0   4.0  3.0  16.0  300.0  88.0  -0.7
# 2   3  2013      3    1     2    7.0   7.0  NaN  17.0  300.0  60.0  -1.2
# 3   4  2013      3    1     3    3.0   3.0  5.0  18.0    NaN   NaN  -1.4
# 4   5  2013      3    1     4    3.0   3.0  7.0   NaN  200.0  84.0  -1.9
#
#      PRES  DEWP  RAIN   wd  WSPM station
# 0  1024.5 -21.4   0.0  NNW   5.7  Dongsi
# 1  1025.1 -22.1   0.0   NW   3.9  Dongsi
# 2  1025.3 -24.6   0.0  NNW   5.3  Dongsi
# 3  1026.2 -25.5   0.0    N   4.9  Dongsi
# 4  1027.1 -24.5   0.0  NNW   3.2  Dongsi

# %% [markdown]
# #### Load Tabel Stasiun Guanyuan

# %%
Guanyuan_df = pd.read_csv('https://raw.githubusercontent.com/Rizky-SR/dicoding-analisis-data-dengan-python/main/subimission/data/PRSA_Data_Guanyuan_20130301-20170228.csv')
Guanyuan_df.head()
# Out:
#    No  year  month  day  hour  PM2.5  PM10   SO2   NO2     CO    O3  TEMP  \
# 0   1  2013      3    1     0    4.0   4.0  14.0  20.0  300.0  69.0  -0.7
# 1   2  2013      3    1     1    4.0   4.0  13.0  17.0  300.0  72.0  -1.1
# 2   3  2013      3    1     2    3.0   3.0  10.0  19.0  300.0  69.0  -1.1
# 3   4  2013      3    1     3    3.0   6.0   7.0  24.0  400.0  62.0  -1.4
# 4   5  2013      3    1     4    3.0   6.0   5.0  14.0  400.0  71.0  -2.0
#
#      PRES  DEWP  RAIN   wd  WSPM   station
# 0  1023.0 -18.8   0.0  NNW   4.4  Guanyuan
# 1  1023.2 -18.2   0.0    N   4.7  Guanyuan
# 2  1023.5 -18.2   0.0  NNW   5.6  Guanyuan
# 3  1024.5 -19.4   0.0   NW   3.1  Guanyuan
# 4  1025.2 -19.5   0.0    N   2.0  Guanyuan

# %% [markdown]
# #### Load Tabel Stasiun Gucheng

# %%
Gucheng_df = pd.read_csv('https://raw.githubusercontent.com/Rizky-SR/dicoding-analisis-data-dengan-python/main/subimission/data/PRSA_Data_Gucheng_20130301-20170228.csv')
Gucheng_df.head()
# Out:
#    No  year  month  day  hour  PM2.5  PM10  SO2  NO2     CO    O3  TEMP  \
# 0   1  2013      3    1     0    6.0  18.0  5.0  NaN  800.0  88.0   0.1
# 1   2  2013      3    1     1    6.0  15.0  5.0  NaN  800.0  88.0  -0.3
# 2   3  2013      3    1     2    5.0  18.0  NaN  NaN  700.0  52.0  -0.7
# 3   4  2013      3    1     3    6.0  20.0  6.0  NaN    NaN   NaN  -1.0
# 4   5  2013      3    1     4    5.0  17.0  5.0  NaN  600.0  73.0  -1.3
#
#      PRES  DEWP  RAIN   wd  WSPM  station
# 0  1021.1 -18.6   0.0   NW   4.4  Gucheng
# 1  1021.5 -19.0   0.0   NW   4.0  Gucheng
# 2  1021.5 -19.8   0.0  WNW   4.6  Gucheng
# 3  1022.7 -21.2   0.0    W   2.8  Gucheng
# 4  1023.0 -21.4   0.0  WNW   3.6  Gucheng

# %% [markdown]
# #### Load Tabel Stasiun Huairou

# %%
Huairou_df = pd.read_csv('https://raw.githubusercontent.com/Rizky-SR/dicoding-analisis-data-dengan-python/main/subimission/data/PRSA_Data_Huairou_20130301-20170228.csv')
Huairou_df.head()
# Out:
#    No  year  month  day  hour  PM2.5  PM10  SO2  NO2     CO    O3  TEMP  \
# 0   1  2013      3    1     0    7.0   7.0  3.0  2.0  100.0  91.0  -2.3
# 1   2  2013      3    1     1    4.0   4.0  3.0  NaN  100.0  92.0  -2.7
# 2   3  2013      3    1     2    4.0   4.0  NaN  NaN  100.0  91.0  -3.2
# 3   4  2013      3    1     3    3.0   3.0  3.0  2.0    NaN   NaN  -3.3
# 4   5  2013      3    1     4    3.0   3.0  7.0  NaN  300.0  86.0  -4.1
#
#      PRES  DEWP  RAIN   wd  WSPM  station
# 0  1020.3 -20.7   0.0  WNW   3.1  Huairou
# 1  1020.8 -20.5   0.0  NNW   1.5  Huairou
# 2  1020.6 -21.4   0.0   NW   1.8  Huairou
# 3  1021.3 -23.7   0.0  NNW   2.4  Huairou
# 4  1022.1 -22.7   0.0  NNW   2.2  Huairou

# %% [markdown]
# #### Load Tabel Stasiun Nongzhanguan

# %%
Nongzhanguan_df = pd.read_csv('https://raw.githubusercontent.com/Rizky-SR/dicoding-analisis-data-dengan-python/main/subimission/data/PRSA_Data_Nongzhanguan_20130301-20170228.csv')
Nongzhanguan_df.head()
# Out:
#    No  year  month  day  hour  PM2.5  PM10  SO2   NO2     CO    O3  TEMP  \
# 0   1  2013      3    1     0    5.0  14.0  4.0  12.0  200.0  85.0  -0.5
# 1   2  2013      3    1     1    8.0  12.0  6.0  14.0  200.0  84.0  -0.7
# 2   3  2013      3    1     2    3.0   6.0  5.0  14.0  200.0  83.0  -1.2
# 3   4  2013      3    1     3    5.0   5.0  5.0  14.0  200.0  84.0  -1.4
# 4   5  2013      3    1     4    5.0   5.0  6.0  21.0  200.0  77.0  -1.9
#
#      PRES  DEWP  RAIN   wd  WSPM       station
# 0  1024.5 -21.4   0.0  NNW   5.7  Nongzhanguan
# 1  1025.1 -22.1   0.0   NW   3.9  Nongzhanguan
# 2  1025.3 -24.6   0.0  NNW   5.3  Nongzhanguan
# 3  1026.2 -25.5   0.0    N   4.9  Nongzhanguan
# 4  1027.1 -24.5   0.0  NNW   3.2  Nongzhanguan

# %% [markdown]
# #### Load Tabel Stasiun Shunyi

# %%
Shunyi_df = pd.read_csv('https://raw.githubusercontent.com/Rizky-SR/dicoding-analisis-data-dengan-python/main/subimission/data/PRSA_Data_Shunyi_20130301-20170228.csv')
Shunyi_df.head()
# Out:
#    No  year  month  day  hour  PM2.5  PM10  SO2  NO2     CO    O3  TEMP  \
# 0   1  2013      3    1     0    3.0   6.0  3.0  8.0  300.0  44.0  -0.9
# 1   2  2013      3    1     1   12.0  12.0  3.0  7.0  300.0  47.0  -1.1
# 2   3  2013      3    1     2   14.0  14.0  NaN  7.0  200.0  22.0  -1.7
# 3   4  2013      3    1     3   12.0  12.0  3.0  5.0    NaN   NaN  -2.1
# 4   5  2013      3    1     4   12.0  12.0  3.0  NaN  200.0  11.0  -2.4
#
#      PRES  DEWP  RAIN  wd  WSPM station
# 0  1025.8 -20.5   0.0  NW   9.3  Shunyi
# 1  1026.1 -21.3   0.0  NW   9.4  Shunyi
# 2  1026.2 -23.0   0.0  NW   8.6  Shunyi
# 3  1027.3 -23.3   0.0  NW   6.6  Shunyi
# 4  1027.7 -22.9   0.0  NW   4.5  Shunyi

# %% [markdown]
# #### Load Tabel Stasiun Tiantan

# %%
Tiantan_df = pd.read_csv('https://raw.githubusercontent.com/Rizky-SR/dicoding-analisis-data-dengan-python/main/subimission/data/PRSA_Data_Tiantan_20130301-20170228.csv')
Tiantan_df.head()
# Out:
#    No  year  month  day  hour  PM2.5  PM10  SO2   NO2     CO    O3  TEMP  \
# 0   1  2013      3    1     0    6.0   6.0  4.0   8.0  300.0  81.0  -0.5
# 1   2  2013      3    1     1    6.0  29.0  5.0   9.0  300.0  80.0  -0.7
# 2   3  2013      3    1     2    6.0   6.0  4.0  12.0  300.0  75.0  -1.2
# 3   4  2013      3    1     3    6.0   6.0  4.0  12.0  300.0  74.0  -1.4
# 4   5  2013      3    1     4    5.0   5.0  7.0  15.0  400.0  70.0  -1.9
#
#      PRES  DEWP  RAIN   wd  WSPM  station
# 0  1024.5 -21.4   0.0  NNW   5.7  Tiantan
# 1  1025.1 -22.1   0.0   NW   3.9  Tiantan
# 2  1025.3 -24.6   0.0  NNW   5.3  Tiantan
# 3  1026.2 -25.5   0.0    N   4.9  Tiantan
# 4  1027.1 -24.5   0.0  NNW   3.2  Tiantan

# %% [markdown]
# #### Load Tabel Stasiun Wanliu

# %%
Wanliu_df = pd.read_csv('https://raw.githubusercontent.com/Rizky-SR/dicoding-analisis-data-dengan-python/main/subimission/data/PRSA_Data_Wanliu_20130301-20170228.csv')
Wanliu_df.head()
# Out:
#    No  year  month  day  hour  PM2.5  PM10  SO2   NO2     CO    O3  TEMP  \
# 0   1  2013      3    1     0    8.0   8.0  6.0  28.0  400.0  52.0  -0.7
# 1   2  2013      3    1     1    9.0   9.0  6.0  28.0  400.0  50.0  -1.1
# 2   3  2013      3    1     2    3.0   6.0  NaN  19.0  400.0  55.0  -1.1
# 3   4  2013      3    1     3   11.0  30.0  8.0  14.0    NaN   NaN  -1.4
# 4   5  2013      3    1     4    3.0  13.0  9.0   NaN  300.0  54.0  -2.0
#
#      PRES  DEWP  RAIN   wd  WSPM station
# 0  1023.0 -18.8   0.0  NNW   4.4  Wanliu
# 1  1023.2 -18.2   0.0    N   4.7  Wanliu
# 2  1023.5 -18.2   0.0  NNW   5.6  Wanliu
# 3  1024.5 -19.4   0.0   NW   3.1  Wanliu
# 4  1025.2 -19.5   0.0    N   2.0  Wanliu

# %% [markdown]
# #### Load Tabel Stasiun Wanshouxigong

# %%
Wanshouxigong_df = pd.read_csv('https://raw.githubusercontent.com/Rizky-SR/dicoding-analisis-data-dengan-python/main/subimission/data/PRSA_Data_Wanshouxigong_20130301-20170228.csv')
Wanshouxigong_df.head()
# Out:
#    No  year  month  day  hour  PM2.5  PM10  SO2   NO2     CO    O3  TEMP  \
# 0   1  2013      3    1     0    9.0   9.0  6.0  17.0  200.0  62.0   0.3
# 1   2  2013      3    1     1   11.0  11.0  7.0  14.0  200.0  66.0  -0.1
# 2   3  2013      3    1     2    8.0   8.0  NaN  16.0  200.0  59.0  -0.6
# 3   4  2013      3    1     3    8.0   8.0  3.0  16.0    NaN   NaN  -0.7
# 4   5  2013      3    1     4    8.0   8.0  3.0   NaN  300.0  36.0  -0.9
#
#      PRES  DEWP  RAIN   wd  WSPM        station
# 0  1021.9 -19.0   0.0  WNW   2.0  Wanshouxigong
# 1  1022.4 -19.3   0.0  WNW   4.4  Wanshouxigong
# 2  1022.6 -19.7   0.0  WNW   4.7  Wanshouxigong
# 3  1023.5 -20.9   0.0   NW   2.6  Wanshouxigong
# 4  1024.1 -21.7   0.0  WNW   2.5  Wanshouxigong

# %% [markdown]
# ### Assessing Data

# %% [markdown]
# #### Menilai Data Aotizhongxin_df

# %%
Aotizhongxin_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 35064 entries, 0 to 35063
# Data columns (total 18 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   No       35064 non-null  int64
#  1   year     35064 non-null  int64
#  2   month    35064 non-null  int64
#  3   day      35064 non-null  int64
#  4   hour     35064 non-null  int64
#  5   PM2.5    34139 non-null  float64
#  6   PM10     34346 non-null  float64
#  7   SO2      34129 non-null  float64
#  8   NO2      34041 non-null  float64
#  9   CO       33288 non-null  float64
#  10  O3       33345 non-null  float64
#  11  TEMP     35044 non-null  float64
#  12  PRES     35044 non-null  float64
#  13  DEWP     35044 non-null  float64
#  14  RAIN     35044 non-null  float64
#  15  wd       34983 non-null  object
#  16  WSPM     35050 non-null  float64
#  17  station  35064 non-null  object
# dtypes: float64(11), int64(5), object(2)
# memory usage: 4.8+ MB

# %%
Aotizhongxin_df.isna().sum()
# Out:
# No            0
# year          0
# month         0
# day           0
# hour          0
# PM2.5       925
# PM10        718
# SO2         935
# NO2        1023
# CO         1776
# O3         1719
# TEMP         20
# PRES         20
# DEWP         20
# RAIN         20
# wd           81
# WSPM         14
# station       0
# dtype: int64

# %%
print("Jumlah duplikasi: ", Aotizhongxin_df.duplicated().sum())
# Out:
# Jumlah duplikasi:  0

# %%
Aotizhongxin_df.describe()
# Out:
#                  No          year         month           day          hour  \
# count  35064.000000  35064.000000  35064.000000  35064.000000  35064.000000
# mean   17532.500000   2014.662560      6.522930     15.729637     11.500000
# std    10122.249256      1.177213      3.448752      8.800218      6.922285
# min        1.000000   2013.000000      1.000000      1.000000      0.000000
# 25%     8766.750000   2014.000000      4.000000      8.000000      5.750000
# 50%    17532.500000   2015.000000      7.000000     16.000000     11.500000
# 75%    26298.250000   2016.000000     10.000000     23.000000     17.250000
# max    35064.000000   2017.000000     12.000000     31.000000     23.000000
#
#               PM2.5          PM10           SO2           NO2            CO  \
# count  34139.000000  34346.000000  34129.000000  34041.000000  33288.000000
# mean      82.773611    110.060391     17.375901     59.305833   1262.945145
# std       82.135694     95.223005     22.823017     37.116200   1221.436236
# min        3.000000      2.000000      0.285600      2.000000    100.000000
# 25%       22.000000     38.000000      3.000000     30.000000    500.000000
# 50%       58.000000     87.000000      9.000000     53.000000    900.000000
# 75%      114.000000    155.000000     21.000000     82.000000   1500.000000
# max      898.000000    984.000000    341.000000    290.000000  10000.000000
#
#                  O3          TEMP          PRES          DEWP          RAIN  \
# count  33345.000000  35044.000000  35044.000000  35044.000000  35044.000000
# mean      56.353358     13.584607   1011.846920      3.123062      0.067421
# std       57.916327     11.399097     10.404047     13.688896      0.910056
# min        0.214200    -16.800000    985.900000    -35.300000      0.000000
# 25%        8.000000      3.100000   1003.300000     -8.100000      0.000000
# 50%       42.000000     14.500000   1011.400000      3.800000      0.000000
# 75%       82.000000     23.300000   1020.100000     15.600000      0.000000
# max      423.000000     40.500000   1042.000000     28.500000     72.500000
#
#                WSPM
# count  35050.000000
# mean       1.708496
# std        1.204071
# min        0.000000
# 25%        0.900000
# 50%        1.400000
# 75%        2.200000
# max       11.200000

# %% [markdown]
# #### Menilai Data Changping_df

# %%
Changping_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 35064 entries, 0 to 35063
# Data columns (total 18 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   No       35064 non-null  int64
#  1   year     35064 non-null  int64
#  2   month    35064 non-null  int64
#  3   day      35064 non-null  int64
#  4   hour     35064 non-null  int64
#  5   PM2.5    34290 non-null  float64
#  6   PM10     34482 non-null  float64
#  7   SO2      34436 non-null  float64
#  8   NO2      34397 non-null  float64
#  9   CO       33543 non-null  float64
#  10  O3       34460 non-null  float64
#  11  TEMP     35011 non-null  float64
#  12  PRES     35014 non-null  float64
#  13  DEWP     35011 non-null  float64
#  14  RAIN     35013 non-null  float64
#  15  wd       34924 non-null  object
#  16  WSPM     35021 non-null  float64
#  17  station  35064 non-null  object
# dtypes: float64(11), int64(5), object(2)
# memory usage: 4.8+ MB

# %%
Changping_df.isna().sum()
# Out:
# No            0
# year          0
# month         0
# day           0
# hour          0
# PM2.5       774
# PM10        582
# SO2         628
# NO2         667
# CO         1521
# O3          604
# TEMP         53
# PRES         50
# DEWP         53
# RAIN         51
# wd          140
# WSPM         43
# station       0
# dtype: int64

# %%
print("Jumlah duplikasi: ", Changping_df.duplicated().sum())
# Out:
# Jumlah duplikasi:  0

# %%
Changping_df.describe()
# Out:
#                  No          year         month           day          hour  \
# count  35064.000000  35064.000000  35064.000000  35064.000000  35064.000000
# mean   17532.500000   2014.662560      6.522930     15.729637     11.500000
# std    10122.249256      1.177213      3.448752      8.800218      6.922285
# min        1.000000   2013.000000      1.000000      1.000000      0.000000
# 25%     8766.750000   2014.000000      4.000000      8.000000      5.750000
# 50%    17532.500000   2015.000000      7.000000     16.000000     11.500000
# 75%    26298.250000   2016.000000     10.000000     23.000000     17.250000
# max    35064.000000   2017.000000     12.000000     31.000000     23.000000
#
#               PM2.5          PM10           SO2           NO2            CO  \
# count  34290.000000  34482.000000  34436.000000  34397.000000  33543.000000
# mean      71.099743     94.657871     14.958906     44.182086   1152.301345
# std       72.326926     83.441738     20.975331     29.519796   1103.056282
# min        2.000000      2.000000      0.285600      1.847700    100.000000
# 25%       18.000000     34.000000      2.000000     22.000000    500.000000
# 50%       46.000000     72.000000      7.000000     36.000000    800.000000
# 75%      100.000000    131.000000     18.000000     60.358200   1400.000000
# max      882.000000    999.000000    310.000000    226.000000  10000.000000
#
#                  O3          TEMP          PRES          DEWP          RAIN  \
# count  34460.000000  35011.000000  35014.000000  35011.000000  35013.000000
# mean      57.940003     13.686111   1007.760278      1.505495      0.060366
# std       54.316674     11.365313     10.225664     13.822099      0.752899
# min        0.214200    -16.600000    982.400000    -35.100000      0.000000
# 25%       15.636600      3.400000    999.300000    -10.200000      0.000000
# 50%       46.000000     14.700000   1007.400000      1.800000      0.000000
# 75%       80.000000     23.300000   1016.000000     14.200000      0.000000
# max      429.000000     41.400000   1036.500000     27.200000     52.100000
#
#                WSPM
# count  35021.000000
# mean       1.853836
# std        1.309808
# min        0.000000
# 25%        1.000000
# 50%        1.500000
# 75%        2.300000
# max       10.000000

# %% [markdown]
# #### Menilai Data Dingling_df

# %%
Dingling_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 35064 entries, 0 to 35063
# Data columns (total 18 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   No       35064 non-null  int64
#  1   year     35064 non-null  int64
#  2   month    35064 non-null  int64
#  3   day      35064 non-null  int64
#  4   hour     35064 non-null  int64
#  5   PM2.5    34285 non-null  float64
#  6   PM10     34408 non-null  float64
#  7   SO2      34334 non-null  float64
#  8   NO2      33830 non-null  float64
#  9   CO       33052 non-null  float64
#  10  O3       33850 non-null  float64
#  11  TEMP     35011 non-null  float64
#  12  PRES     35014 non-null  float64
#  13  DEWP     35011 non-null  float64
#  14  RAIN     35013 non-null  float64
#  15  wd       34924 non-null  object
#  16  WSPM     35021 non-null  float64
#  17  station  35064 non-null  object
# dtypes: float64(11), int64(5), object(2)
# memory usage: 4.8+ MB

# %%
Dingling_df.isna().sum()
# Out:
# No            0
# year          0
# month         0
# day           0
# hour          0
# PM2.5       779
# PM10        656
# SO2         730
# NO2        1234
# CO         2012
# O3         1214
# TEMP         53
# PRES         50
# DEWP         53
# RAIN         51
# wd          140
# WSPM         43
# station       0
# dtype: int64

# %%
print("Jumlah duplikasi: ", Dingling_df.duplicated().sum())
# Out:
# Jumlah duplikasi:  0

# %%
Dingling_df.describe()
# Out:
#                  No          year         month           day          hour  \
# count  35064.000000  35064.000000  35064.000000  35064.000000  35064.000000
# mean   17532.500000   2014.662560      6.522930     15.729637     11.500000
# std    10122.249256      1.177213      3.448752      8.800218      6.922285
# min        1.000000   2013.000000      1.000000      1.000000      0.000000
# 25%     8766.750000   2014.000000      4.000000      8.000000      5.750000
# 50%    17532.500000   2015.000000      7.000000     16.000000     11.500000
# 75%    26298.250000   2016.000000     10.000000     23.000000     17.250000
# max    35064.000000   2017.000000     12.000000     31.000000     23.000000
#
#               PM2.5          PM10           SO2           NO2            CO  \
# count  34285.000000  34408.000000  34334.000000  33830.000000  33052.000000
# mean      65.989497     83.739723     11.749650     27.585467    904.896073
# std       72.267723     79.541685     15.519259     26.383882    903.306220
# min        3.000000      2.000000      0.285600      1.026500    100.000000
# 25%       14.000000     26.000000      2.000000      9.000000    300.000000
# 50%       41.000000     60.000000      5.000000     19.000000    600.000000
# 75%       93.000000    117.000000     15.000000     38.000000   1200.000000
# max      881.000000    905.000000    156.000000    205.000000  10000.000000
#
#                  O3          TEMP          PRES          DEWP          RAIN  \
# count  33850.000000  35011.000000  35014.000000  35011.000000  35013.000000
# mean      68.548371     13.686111   1007.760278      1.505495      0.060366
# std       53.764424     11.365313     10.225664     13.822099      0.752899
# min        0.214200    -16.600000    982.400000    -35.100000      0.000000
# 25%       31.000000      3.400000    999.300000    -10.200000      0.000000
# 50%       61.000000     14.700000   1007.400000      1.800000      0.000000
# 75%       90.000000     23.300000   1016.000000     14.200000      0.000000
# max      500.000000     41.400000   1036.500000     27.200000     52.100000
#
#                WSPM
# count  35021.000000
# mean       1.853836
# std        1.309808
# min        0.000000
# 25%        1.000000
# 50%        1.500000
# 75%        2.300000
# max       10.000000

# %% [markdown]
# #### Menilai Data Dongsi_df

# %%
Dongsi_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 35064 entries, 0 to 35063
# Data columns (total 18 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   No       35064 non-null  int64
#  1   year     35064 non-null  int64
#  2   month    35064 non-null  int64
#  3   day      35064 non-null  int64
#  4   hour     35064 non-null  int64
#  5   PM2.5    34314 non-null  float64
#  6   PM10     34511 non-null  float64
#  7   SO2      34401 non-null  float64
#  8   NO2      33463 non-null  float64
#  9   CO       31867 non-null  float64
#  10  O3       34400 non-null  float64
#  11  TEMP     35044 non-null  float64
#  12  PRES     35044 non-null  float64
#  13  DEWP     35044 non-null  float64
#  14  RAIN     35044 non-null  float64
#  15  wd       34986 non-null  object
#  16  WSPM     35050 non-null  float64
#  17  station  35064 non-null  object
# dtypes: float64(11), int64(5), object(2)
# memory usage: 4.8+ MB

# %%
Dongsi_df.isna().sum()
# Out:
# No            0
# year          0
# month         0
# day           0
# hour          0
# PM2.5       750
# PM10        553
# SO2         663
# NO2        1601
# CO         3197
# O3          664
# TEMP         20
# PRES         20
# DEWP         20
# RAIN         20
# wd           78
# WSPM         14
# station       0
# dtype: int64

# %%
print("Jumlah duplikasi: ", Dongsi_df.duplicated().sum())
# Out:
# Jumlah duplikasi:  0

# %%
Dongsi_df.describe()
# Out:
#                  No          year         month           day          hour  \
# count  35064.000000  35064.000000  35064.000000  35064.000000  35064.000000
# mean   17532.500000   2014.662560      6.522930     15.729637     11.500000
# std    10122.249256      1.177213      3.448752      8.800218      6.922285
# min        1.000000   2013.000000      1.000000      1.000000      0.000000
# 25%     8766.750000   2014.000000      4.000000      8.000000      5.750000
# 50%    17532.500000   2015.000000      7.000000     16.000000     11.500000
# 75%    26298.250000   2016.000000     10.000000     23.000000     17.250000
# max    35064.000000   2017.000000     12.000000     31.000000     23.000000
#
#               PM2.5          PM10           SO2           NO2            CO  \
# count  34314.000000  34511.000000  34401.000000  33463.000000  31867.000000
# mean      86.194297    110.336742     18.531107     53.699443   1330.069131
# std       86.575127     98.219860     22.905655     33.959230   1191.305887
# min        3.000000      2.000000      0.285600      2.000000    100.000000
# 25%       22.000000     38.000000      4.000000     27.000000    600.000000
# 50%       61.000000     86.000000     10.000000     47.000000   1000.000000
# 75%      119.000000    151.000000     24.000000     73.000000   1700.000000
# max      737.000000    955.000000    300.000000    258.000000  10000.000000
#
#                  O3          TEMP          PRES          DEWP          RAIN  \
# count  34400.000000  35044.000000  35044.000000  35044.000000  35044.000000
# mean      57.210637     13.671490   1012.547419      2.447535      0.064020
# std       58.033275     11.458418     10.266059     13.810696      0.786282
# min        0.642600    -16.800000    987.100000    -35.300000      0.000000
# 25%       12.000000      3.100000   1004.000000     -8.800000      0.000000
# 50%       44.125200     14.600000   1012.200000      3.000000      0.000000
# 75%       81.000000     23.500000   1020.900000     15.000000      0.000000
# max     1071.000000     41.100000   1042.000000     28.800000     46.400000
#
#                WSPM
# count  35050.000000
# mean       1.860785
# std        1.280368
# min        0.000000
# 25%        1.000000
# 50%        1.500000
# 75%        2.400000
# max       10.500000

# %% [markdown]
# #### Menilai Data Guanyuan_df

# %%
Guanyuan_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 35064 entries, 0 to 35063
# Data columns (total 18 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   No       35064 non-null  int64
#  1   year     35064 non-null  int64
#  2   month    35064 non-null  int64
#  3   day      35064 non-null  int64
#  4   hour     35064 non-null  int64
#  5   PM2.5    34448 non-null  float64
#  6   PM10     34635 non-null  float64
#  7   SO2      34590 non-null  float64
#  8   NO2      34405 non-null  float64
#  9   CO       33311 non-null  float64
#  10  O3       33891 non-null  float64
#  11  TEMP     35044 non-null  float64
#  12  PRES     35044 non-null  float64
#  13  DEWP     35044 non-null  float64
#  14  RAIN     35044 non-null  float64
#  15  wd       34983 non-null  object
#  16  WSPM     35050 non-null  float64
#  17  station  35064 non-null  object
# dtypes: float64(11), int64(5), object(2)
# memory usage: 4.8+ MB

# %%
Guanyuan_df.isna().sum()
# Out:
# No            0
# year          0
# month         0
# day           0
# hour          0
# PM2.5       616
# PM10        429
# SO2         474
# NO2         659
# CO         1753
# O3         1173
# TEMP         20
# PRES         20
# DEWP         20
# RAIN         20
# wd           81
# WSPM         14
# station       0
# dtype: int64

# %%
print("Jumlah duplikasi: ", Guanyuan_df.duplicated().sum())
# Out:
# Jumlah duplikasi:  0

# %%
Guanyuan_df.describe()
# Out:
#                  No          year         month           day          hour  \
# count  35064.000000  35064.000000  35064.000000  35064.000000  35064.000000
# mean   17532.500000   2014.662560      6.522930     15.729637     11.500000
# std    10122.249256      1.177213      3.448752      8.800218      6.922285
# min        1.000000   2013.000000      1.000000      1.000000      0.000000
# 25%     8766.750000   2014.000000      4.000000      8.000000      5.750000
# 50%    17532.500000   2015.000000      7.000000     16.000000     11.500000
# 75%    26298.250000   2016.000000     10.000000     23.000000     17.250000
# max    35064.000000   2017.000000     12.000000     31.000000     23.000000
#
#               PM2.5          PM10           SO2           NO2            CO  \
# count  34448.000000  34635.000000  34590.000000  34405.000000  33311.000000
# mean      82.933372    109.023303     17.590941     57.901643   1271.294377
# std       80.933497     91.573709     23.600367     35.150857   1164.854945
# min        2.000000      2.000000      1.000000      2.000000    100.000000
# 25%       23.000000     40.000000      3.000000     31.000000    500.000000
# 50%       59.000000     89.000000      8.000000     51.000000    900.000000
# 75%      115.000000    149.000000     22.000000     78.000000   1600.000000
# max      680.000000    999.000000    293.000000    270.000000  10000.000000
#
#                  O3          TEMP          PRES          DEWP          RAIN  \
# count  33891.000000  35044.000000  35044.000000  35044.000000  35044.000000
# mean      55.795044     13.584607   1011.846920      3.123062      0.067421
# std       57.436983     11.399097     10.404047     13.688896      0.910056
# min        0.214200    -16.800000    985.900000    -35.300000      0.000000
# 25%        7.000000      3.100000   1003.300000     -8.100000      0.000000
# 50%       41.000000     14.500000   1011.400000      3.800000      0.000000
# 75%       81.000000     23.300000   1020.100000     15.600000      0.000000
# max      415.000000     40.500000   1042.000000     28.500000     72.500000
#
#                WSPM
# count  35050.000000
# mean       1.708496
# std        1.204071
# min        0.000000
# 25%        0.900000
# 50%        1.400000
# 75%        2.200000
# max       11.200000

# %% [markdown]
# #### Menilai Data Gucheng_df

# %%
Gucheng_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 35064 entries, 0 to 35063
# Data columns (total 18 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   No       35064 non-null  int64
#  1   year     35064 non-null  int64
#  2   month    35064 non-null  int64
#  3   day      35064 non-null  int64
#  4   hour     35064 non-null  int64
#  5   PM2.5    34418 non-null  float64
#  6   PM10     34683 non-null  float64
#  7   SO2      34557 non-null  float64
#  8   NO2      34396 non-null  float64
#  9   CO       33663 non-null  float64
#  10  O3       34335 non-null  float64
#  11  TEMP     35013 non-null  float64
#  12  PRES     35014 non-null  float64
#  13  DEWP     35013 non-null  float64
#  14  RAIN     35021 non-null  float64
#  15  wd       34905 non-null  object
#  16  WSPM     35022 non-null  float64
#  17  station  35064 non-null  object
# dtypes: float64(11), int64(5), object(2)
# memory usage: 4.8+ MB

# %%
Gucheng_df.isna().sum()
# Out:
# No            0
# year          0
# month         0
# day           0
# hour          0
# PM2.5       646
# PM10        381
# SO2         507
# NO2         668
# CO         1401
# O3          729
# TEMP         51
# PRES         50
# DEWP         51
# RAIN         43
# wd          159
# WSPM         42
# station       0
# dtype: int64

# %%
print("Jumlah duplikasi: ", Gucheng_df.duplicated().sum())
# Out:
# Jumlah duplikasi:  0

# %%
Gucheng_df.describe()
# Out:
#                  No          year         month           day          hour  \
# count  35064.000000  35064.000000  35064.000000  35064.000000  35064.000000
# mean   17532.500000   2014.662560      6.522930     15.729637     11.500000
# std    10122.249256      1.177213      3.448752      8.800218      6.922285
# min        1.000000   2013.000000      1.000000      1.000000      0.000000
# 25%     8766.750000   2014.000000      4.000000      8.000000      5.750000
# 50%    17532.500000   2015.000000      7.000000     16.000000     11.500000
# 75%    26298.250000   2016.000000     10.000000     23.000000     17.250000
# max    35064.000000   2017.000000     12.000000     31.000000     23.000000
#
#               PM2.5          PM10           SO2           NO2            CO  \
# count  34418.000000  34683.000000  34557.000000  34396.000000  33663.000000
# mean      83.852089    118.861978     15.366162     55.871075   1323.974423
# std       82.796445     96.742626     21.204526     36.473860   1208.957772
# min        2.000000      2.000000      0.285600      2.000000    100.000000
# 25%       24.000000     45.000000      2.000000     26.000000    600.000000
# 50%       60.000000     99.000000      7.000000     50.000000    900.000000
# 75%      115.750000    167.000000     20.000000     79.000000   1600.000000
# max      770.000000    994.000000    500.000000    276.000000  10000.000000
#
#                  O3          TEMP          PRES          DEWP          RAIN  \
# count  34335.000000  35013.000000  35014.000000  35013.000000  35021.000000
# mean      57.694879     13.864524   1008.829592      2.610442      0.064453
# std       57.019587     11.292857     10.103256     13.782991      0.838654
# min        0.214200    -15.600000    984.000000    -34.600000      0.000000
# 25%       10.000000      3.600000   1000.500000     -8.900000      0.000000
# 50%       45.000000     14.800000   1008.500000      3.000000      0.000000
# 75%       83.000000     23.500000   1017.000000     15.300000      0.000000
# max      450.000000     41.600000   1038.100000     27.400000     41.900000
#
#                WSPM
# count  35022.000000
# mean       1.343310
# std        1.151064
# min        0.000000
# 25%        0.600000
# 50%        1.000000
# 75%        1.800000
# max       12.000000

# %% [markdown]
# #### Menilai Data Huairou_df

# %%
Huairou_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 35064 entries, 0 to 35063
# Data columns (total 18 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   No       35064 non-null  int64
#  1   year     35064 non-null  int64
#  2   month    35064 non-null  int64
#  3   day      35064 non-null  int64
#  4   hour     35064 non-null  int64
#  5   PM2.5    34111 non-null  float64
#  6   PM10     34287 non-null  float64
#  7   SO2      34084 non-null  float64
#  8   NO2      33425 non-null  float64
#  9   CO       33642 non-null  float64
#  10  O3       33913 non-null  float64
#  11  TEMP     35013 non-null  float64
#  12  PRES     35011 non-null  float64
#  13  DEWP     35011 non-null  float64
#  14  RAIN     35009 non-null  float64
#  15  wd       34762 non-null  object
#  16  WSPM     35015 non-null  float64
#  17  station  35064 non-null  object
# dtypes: float64(11), int64(5), object(2)
# memory usage: 4.8+ MB

# %%
Huairou_df.isna().sum()
# Out:
# No            0
# year          0
# month         0
# day           0
# hour          0
# PM2.5       953
# PM10        777
# SO2         980
# NO2        1639
# CO         1422
# O3         1151
# TEMP         51
# PRES         53
# DEWP         53
# RAIN         55
# wd          302
# WSPM         49
# station       0
# dtype: int64

# %%
print("Jumlah duplikasi: ", Huairou_df.duplicated().sum())
# Out:
# Jumlah duplikasi:  0

# %%
Huairou_df.describe()
# Out:
#                  No          year         month           day          hour  \
# count  35064.000000  35064.000000  35064.000000  35064.000000  35064.000000
# mean   17532.500000   2014.662560      6.522930     15.729637     11.500000
# std    10122.249256      1.177213      3.448752      8.800218      6.922285
# min        1.000000   2013.000000      1.000000      1.000000      0.000000
# 25%     8766.750000   2014.000000      4.000000      8.000000      5.750000
# 50%    17532.500000   2015.000000      7.000000     16.000000     11.500000
# 75%    26298.250000   2016.000000     10.000000     23.000000     17.250000
# max    35064.000000   2017.000000     12.000000     31.000000     23.000000
#
#               PM2.5          PM10           SO2           NO2            CO  \
# count  34111.000000  34287.000000  34084.000000  33425.000000  33642.000000
# mean      69.626367     91.482690     12.121553     32.497250   1022.554545
# std       71.224916     83.289578     18.896912     26.489531    898.738241
# min        2.000000      2.000000      0.285600      1.026500    100.000000
# 25%       17.000000     28.000000      2.000000     12.000000    400.000000
# 50%       47.000000     69.000000      4.000000     25.000000    800.000000
# 75%       98.000000    131.000000     14.000000     46.000000   1300.000000
# max      762.000000    993.000000    315.000000    231.000000  10000.000000
#
#                  O3          TEMP          PRES          DEWP          RAIN  \
# count  33913.000000  35013.000000  35011.000000  35011.000000  35009.000000
# mean      59.824713     12.445426   1007.598568      2.238619      0.067940
# std       54.605746     11.751103     10.022101     14.052541      0.849046
# min        0.214200    -19.900000    982.800000    -43.400000      0.000000
# 25%       18.000000      2.100000    999.300000     -9.600000      0.000000
# 50%       49.000000     13.600000   1007.300000      2.700000      0.000000
# 75%       83.000000     22.300000   1015.500000     15.300000      0.000000
# max      444.000000     40.300000   1036.500000     29.100000     45.900000
#
#                WSPM
# count  35015.000000
# mean       1.652021
# std        1.199143
# min        0.000000
# 25%        0.900000
# 50%        1.300000
# 75%        2.000000
# max       12.900000

# %% [markdown]
# #### Menilai Data Nongzhanguan_df

# %%
Nongzhanguan_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 35064 entries, 0 to 35063
# Data columns (total 18 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   No       35064 non-null  int64
#  1   year     35064 non-null  int64
#  2   month    35064 non-null  int64
#  3   day      35064 non-null  int64
#  4   hour     35064 non-null  int64
#  5   PM2.5    34436 non-null  float64
#  6   PM10     34624 non-null  float64
#  7   SO2      34618 non-null  float64
#  8   NO2      34372 non-null  float64
#  9   CO       33858 non-null  float64
#  10  O3       34558 non-null  float64
#  11  TEMP     35044 non-null  float64
#  12  PRES     35044 non-null  float64
#  13  DEWP     35044 non-null  float64
#  14  RAIN     35044 non-null  float64
#  15  wd       34986 non-null  object
#  16  WSPM     35050 non-null  float64
#  17  station  35064 non-null  object
# dtypes: float64(11), int64(5), object(2)
# memory usage: 4.8+ MB

# %%
Nongzhanguan_df.isna().sum()
# Out:
# No            0
# year          0
# month         0
# day           0
# hour          0
# PM2.5       628
# PM10        440
# SO2         446
# NO2         692
# CO         1206
# O3          506
# TEMP         20
# PRES         20
# DEWP         20
# RAIN         20
# wd           78
# WSPM         14
# station       0
# dtype: int64

# %%
print("Jumlah duplikasi: ", Nongzhanguan_df.duplicated().sum())
# Out:
# Jumlah duplikasi:  0

# %%
Nongzhanguan_df.describe()
# Out:
#                  No          year         month           day          hour  \
# count  35064.000000  35064.000000  35064.000000  35064.000000  35064.000000
# mean   17532.500000   2014.662560      6.522930     15.729637     11.500000
# std    10122.249256      1.177213      3.448752      8.800218      6.922285
# min        1.000000   2013.000000      1.000000      1.000000      0.000000
# 25%     8766.750000   2014.000000      4.000000      8.000000      5.750000
# 50%    17532.500000   2015.000000      7.000000     16.000000     11.500000
# 75%    26298.250000   2016.000000     10.000000     23.000000     17.250000
# max    35064.000000   2017.000000     12.000000     31.000000     23.000000
#
#               PM2.5          PM10           SO2           NO2            CO  \
# count  34436.000000  34624.000000  34618.000000  34372.000000  33858.000000
# mean      84.838483    108.991096     18.689242     58.097172   1324.350198
# std       86.225344     95.341177     24.280665     36.297740   1245.166124
# min        2.000000      2.000000      0.571200      2.000000    100.000000
# 25%       22.000000     38.000000      3.000000     29.000000    500.000000
# 50%       59.000000     85.000000      9.000000     51.000000    900.000000
# 75%      116.000000    149.000000     23.000000     80.000000   1600.000000
# max      844.000000    995.000000    257.000000    273.000000  10000.000000
#
#                  O3          TEMP          PRES          DEWP          RAIN  \
# count  34558.000000  35044.000000  35044.000000  35044.000000  35044.000000
# mean      58.534682     13.671490   1012.547419      2.447535      0.064020
# std       58.401448     11.458418     10.266059     13.810696      0.786282
# min        0.214200    -16.800000    987.100000    -35.300000      0.000000
# 25%       10.000000      3.100000   1004.000000     -8.800000      0.000000
# 50%       45.000000     14.600000   1012.200000      3.000000      0.000000
# 75%       84.000000     23.500000   1020.900000     15.000000      0.000000
# max      390.000000     41.100000   1042.000000     28.800000     46.400000
#
#                WSPM
# count  35050.000000
# mean       1.860785
# std        1.280368
# min        0.000000
# 25%        1.000000
# 50%        1.500000
# 75%        2.400000
# max       10.500000

# %% [markdown]
# #### Menilai Data Shunyi_df

# %%
Shunyi_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 35064 entries, 0 to 35063
# Data columns (total 18 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   No       35064 non-null  int64
#  1   year     35064 non-null  int64
#  2   month    35064 non-null  int64
#  3   day      35064 non-null  int64
#  4   hour     35064 non-null  int64
#  5   PM2.5    34151 non-null  float64
#  6   PM10     34516 non-null  float64
#  7   SO2      33768 non-null  float64
#  8   NO2      33699 non-null  float64
#  9   CO       32886 non-null  float64
#  10  O3       33575 non-null  float64
#  11  TEMP     35013 non-null  float64
#  12  PRES     35013 non-null  float64
#  13  DEWP     35010 non-null  float64
#  14  RAIN     35013 non-null  float64
#  15  wd       34581 non-null  object
#  16  WSPM     35020 non-null  float64
#  17  station  35064 non-null  object
# dtypes: float64(11), int64(5), object(2)
# memory usage: 4.8+ MB

# %%
Shunyi_df.isna().sum()
# Out:
# No            0
# year          0
# month         0
# day           0
# hour          0
# PM2.5       913
# PM10        548
# SO2        1296
# NO2        1365
# CO         2178
# O3         1489
# TEMP         51
# PRES         51
# DEWP         54
# RAIN         51
# wd          483
# WSPM         44
# station       0
# dtype: int64

# %%
print("Jumlah duplikasi: ", Shunyi_df.duplicated().sum())
# Out:
# Jumlah duplikasi:  0

# %%
Shunyi_df.describe()
# Out:
#                  No          year         month           day          hour  \
# count  35064.000000  35064.000000  35064.000000  35064.000000  35064.000000
# mean   17532.500000   2014.662560      6.522930     15.729637     11.500000
# std    10122.249256      1.177213      3.448752      8.800218      6.922285
# min        1.000000   2013.000000      1.000000      1.000000      0.000000
# 25%     8766.750000   2014.000000      4.000000      8.000000      5.750000
# 50%    17532.500000   2015.000000      7.000000     16.000000     11.500000
# 75%    26298.250000   2016.000000     10.000000     23.000000     17.250000
# max    35064.000000   2017.000000     12.000000     31.000000     23.000000
#
#               PM2.5          PM10           SO2           NO2            CO  \
# count  34151.000000  34516.000000  33768.000000  33699.000000  32886.000000
# mean      79.491602     98.737026     13.572039     43.908865   1187.063979
# std       81.231739     89.143718     19.572068     30.996828   1156.374102
# min        2.000000      2.000000      0.285600      2.000000    100.000000
# 25%       19.000000     31.000000      2.000000     19.000000    400.000000
# 50%       55.000000     77.000000      5.000000     37.000000    800.000000
# 75%      112.000000    138.000000     17.000000     62.000000   1500.000000
# max      941.000000    999.000000    239.000000    258.000000  10000.000000
#
#                  O3          TEMP          PRES          DEWP          RAIN  \
# count  33575.000000  35013.000000  35013.000000  35010.000000  35013.000000
# mean      55.201321     13.387969   1013.061938      2.465036      0.061094
# std       54.873726     11.483588     10.177339     13.726622      0.761668
# min        0.214200    -16.800000    988.000000    -36.000000      0.000000
# 25%       10.000000      3.000000   1004.700000     -8.800000      0.000000
# 50%       43.000000     14.400000   1012.700000      3.100000      0.000000
# 75%       77.000000     23.200000   1021.000000     15.100000      0.000000
# max      351.716400     40.600000   1042.800000     27.500000     37.300000
#
#                WSPM
# count  35020.000000
# mean       1.807533
# std        1.287817
# min        0.000000
# 25%        1.000000
# 50%        1.500000
# 75%        2.300000
# max       12.800000

# %% [markdown]
# #### Menilai Data Tiantan_df

# %%
Tiantan_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 35064 entries, 0 to 35063
# Data columns (total 18 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   No       35064 non-null  int64
#  1   year     35064 non-null  int64
#  2   month    35064 non-null  int64
#  3   day      35064 non-null  int64
#  4   hour     35064 non-null  int64
#  5   PM2.5    34387 non-null  float64
#  6   PM10     34467 non-null  float64
#  7   SO2      33946 non-null  float64
#  8   NO2      34320 non-null  float64
#  9   CO       33938 non-null  float64
#  10  O3       34221 non-null  float64
#  11  TEMP     35044 non-null  float64
#  12  PRES     35044 non-null  float64
#  13  DEWP     35044 non-null  float64
#  14  RAIN     35044 non-null  float64
#  15  wd       34986 non-null  object
#  16  WSPM     35050 non-null  float64
#  17  station  35064 non-null  object
# dtypes: float64(11), int64(5), object(2)
# memory usage: 4.8+ MB

# %%
Tiantan_df.isna().sum()
# Out:
# No            0
# year          0
# month         0
# day           0
# hour          0
# PM2.5       677
# PM10        597
# SO2        1118
# NO2         744
# CO         1126
# O3          843
# TEMP         20
# PRES         20
# DEWP         20
# RAIN         20
# wd           78
# WSPM         14
# station       0
# dtype: int64

# %%
print("Jumlah duplikasi: ", Tiantan_df.duplicated().sum())
# Out:
# Jumlah duplikasi:  0

# %%
Tiantan_df.describe()
# Out:
#                  No          year         month           day          hour  \
# count  35064.000000  35064.000000  35064.000000  35064.000000  35064.000000
# mean   17532.500000   2014.662560      6.522930     15.729637     11.500000
# std    10122.249256      1.177213      3.448752      8.800218      6.922285
# min        1.000000   2013.000000      1.000000      1.000000      0.000000
# 25%     8766.750000   2014.000000      4.000000      8.000000      5.750000
# 50%    17532.500000   2015.000000      7.000000     16.000000     11.500000
# 75%    26298.250000   2016.000000     10.000000     23.000000     17.250000
# max    35064.000000   2017.000000     12.000000     31.000000     23.000000
#
#               PM2.5          PM10           SO2           NO2            CO  \
# count  34387.000000  34467.000000  33946.000000  34320.000000  33938.000000
# mean      82.164911    106.363672     14.367615     53.162646   1298.303318
# std       80.921384     89.700157     20.144631     31.946224   1170.593297
# min        3.000000      2.000000      0.571200      2.000000    100.000000
# 25%       22.000000     41.000000      3.000000     28.000000    500.000000
# 50%       59.000000     85.000000      7.000000     47.000000    900.000000
# 75%      113.000000    144.000000     17.000000     71.000000   1600.000000
# max      821.000000    988.000000    273.000000    241.000000  10000.000000
#
#                  O3          TEMP          PRES          DEWP          RAIN  \
# count  34221.000000  35044.000000  35044.000000  35044.000000  35044.000000
# mean      55.984297     13.671490   1012.547419      2.447535      0.064020
# std       59.081528     11.458418     10.266059     13.810696      0.786282
# min        0.428400    -16.800000    987.100000    -35.300000      0.000000
# 25%        8.000000      3.100000   1004.000000     -8.800000      0.000000
# 50%       40.000000     14.600000   1012.200000      3.000000      0.000000
# 75%       81.000000     23.500000   1020.900000     15.000000      0.000000
# max      674.000000     41.100000   1042.000000     28.800000     46.400000
#
#                WSPM
# count  35050.000000
# mean       1.860785
# std        1.280368
# min        0.000000
# 25%        1.000000
# 50%        1.500000
# 75%        2.400000
# max       10.500000

# %% [markdown]
# #### Menilai Data Wanliu_df

# %%
Wanliu_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 35064 entries, 0 to 35063
# Data columns (total 18 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   No       35064 non-null  int64
#  1   year     35064 non-null  int64
#  2   month    35064 non-null  int64
#  3   day      35064 non-null  int64
#  4   hour     35064 non-null  int64
#  5   PM2.5    34682 non-null  float64
#  6   PM10     34780 non-null  float64
#  7   SO2      34489 non-null  float64
#  8   NO2      33994 non-null  float64
#  9   CO       33252 non-null  float64
#  10  O3       32957 non-null  float64
#  11  TEMP     35044 non-null  float64
#  12  PRES     35044 non-null  float64
#  13  DEWP     35044 non-null  float64
#  14  RAIN     35044 non-null  float64
#  15  wd       34941 non-null  object
#  16  WSPM     35050 non-null  float64
#  17  station  35064 non-null  object
# dtypes: float64(11), int64(5), object(2)
# memory usage: 4.8+ MB

# %%
Wanliu_df.isna().sum()
# Out:
# No            0
# year          0
# month         0
# day           0
# hour          0
# PM2.5       382
# PM10        284
# SO2         575
# NO2        1070
# CO         1812
# O3         2107
# TEMP         20
# PRES         20
# DEWP         20
# RAIN         20
# wd          123
# WSPM         14
# station       0
# dtype: int64

# %%
print("Jumlah duplikasi: ", Wanliu_df.duplicated().sum())
# Out:
# Jumlah duplikasi:  0

# %%
Wanliu_df.describe()
# Out:
#                  No          year         month           day          hour  \
# count  35064.000000  35064.000000  35064.000000  35064.000000  35064.000000
# mean   17532.500000   2014.662560      6.522930     15.729637     11.500000
# std    10122.249256      1.177213      3.448752      8.800218      6.922285
# min        1.000000   2013.000000      1.000000      1.000000      0.000000
# 25%     8766.750000   2014.000000      4.000000      8.000000      5.750000
# 50%    17532.500000   2015.000000      7.000000     16.000000     11.500000
# 75%    26298.250000   2016.000000     10.000000     23.000000     17.250000
# max    35064.000000   2017.000000     12.000000     31.000000     23.000000
#
#               PM2.5          PM10           SO2           NO2            CO  \
# count  34682.000000  34780.000000  34489.000000  33994.000000  33252.000000
# mean      83.374716    110.464618     18.376481     65.258789   1319.353513
# std       81.905568     92.795065     22.609648     37.996088   1268.114331
# min        2.000000      2.000000      0.285600      1.642400    100.000000
# 25%       23.000000     40.000000      4.000000     36.000000    500.000000
# 50%       59.000000     88.000000     10.000000     60.000000    900.000000
# 75%      116.000000    153.000000     23.000000     88.000000   1600.000000
# max      957.000000    951.000000    282.000000    264.000000  10000.000000
#
#                  O3          TEMP          PRES          DEWP          RAIN  \
# count  32957.000000  35044.000000  35044.000000  35044.000000  35044.000000
# mean      48.873614     13.428865   1011.097536      3.266588      0.068263
# std       55.111740     11.346931     10.355247     13.678060      0.896726
# min        0.214200    -15.800000    985.900000    -34.900000      0.000000
# 25%        4.000000      3.200000   1002.500000     -8.100000      0.000000
# 50%       32.000000     14.300000   1010.800000      4.000000      0.000000
# 75%       73.000000     22.900000   1019.400000     15.800000      0.000000
# max      364.000000     40.500000   1040.300000     28.500000     72.500000
#
#                WSPM
# count  35050.000000
# mean       1.501215
# std        1.104472
# min        0.000000
# 25%        0.800000
# 50%        1.200000
# 75%        2.000000
# max       11.200000

# %% [markdown]
# #### Menilai Data Wanshouxigong_df

# %%
Wanshouxigong_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 35064 entries, 0 to 35063
# Data columns (total 18 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   No       35064 non-null  int64
#  1   year     35064 non-null  int64
#  2   month    35064 non-null  int64
#  3   day      35064 non-null  int64
#  4   hour     35064 non-null  int64
#  5   PM2.5    34368 non-null  float64
#  6   PM10     34580 non-null  float64
#  7   SO2      34395 non-null  float64
#  8   NO2      34310 non-null  float64
#  9   CO       33767 non-null  float64
#  10  O3       33986 non-null  float64
#  11  TEMP     35045 non-null  float64
#  12  PRES     35045 non-null  float64
#  13  DEWP     35045 non-null  float64
#  14  RAIN     35045 non-null  float64
#  15  wd       34985 non-null  object
#  16  WSPM     35051 non-null  float64
#  17  station  35064 non-null  object
# dtypes: float64(11), int64(5), object(2)
# memory usage: 4.8+ MB

# %%
Wanshouxigong_df.isna().sum()
# Out:
# No            0
# year          0
# month         0
# day           0
# hour          0
# PM2.5       696
# PM10        484
# SO2         669
# NO2         754
# CO         1297
# O3         1078
# TEMP         19
# PRES         19
# DEWP         19
# RAIN         19
# wd           79
# WSPM         13
# station       0
# dtype: int64

# %%
print("Jumlah duplikasi: ", Wanshouxigong_df.duplicated().sum())
# Out:
# Jumlah duplikasi:  0

# %%
Wanshouxigong_df.describe()
# Out:
#                  No          year         month           day          hour  \
# count  35064.000000  35064.000000  35064.000000  35064.000000  35064.000000
# mean   17532.500000   2014.662560      6.522930     15.729637     11.500000
# std    10122.249256      1.177213      3.448752      8.800218      6.922285
# min        1.000000   2013.000000      1.000000      1.000000      0.000000
# 25%     8766.750000   2014.000000      4.000000      8.000000      5.750000
# 50%    17532.500000   2015.000000      7.000000     16.000000     11.500000
# 75%    26298.250000   2016.000000     10.000000     23.000000     17.250000
# max    35064.000000   2017.000000     12.000000     31.000000     23.000000
#
#               PM2.5          PM10           SO2          NO2            CO  \
# count  34368.000000  34580.000000  34395.000000  34310.00000  33767.000000
# mean      85.024136    112.223459     17.148603     55.52956   1370.395031
# std       85.975981     97.593210     23.940834     35.80805   1223.139114
# min        3.000000      2.000000      0.285600      2.00000    100.000000
# 25%       23.000000     39.000000      3.000000     28.00000    600.000000
# 50%       60.000000     91.000000      8.000000     49.00000   1000.000000
# 75%      116.000000    154.000000     21.000000     77.00000   1700.000000
# max      999.000000    961.000000    411.000000    251.00000   9800.000000
#
#                  O3          TEMP          PRES          DEWP          RAIN  \
# count  33986.000000  35045.000000  35045.000000  35045.000000  35045.000000
# mean      56.229904     13.784477   1011.511804      2.707442      0.064320
# std       57.082710     11.385156     10.570928     13.704139      0.796981
# min        0.214200    -16.800000    985.100000    -35.300000      0.000000
# 25%        8.000000      3.400000   1002.800000     -8.500000      0.000000
# 50%       42.000000     14.800000   1011.000000      3.300000      0.000000
# 75%       82.000000     23.500000   1020.000000     15.200000      0.000000
# max      358.000000     40.600000   1042.000000     28.500000     46.400000
#
#                WSPM
# count  35051.000000
# mean       1.745314
# std        1.206355
# min        0.000000
# 25%        0.900000
# 50%        1.400000
# 75%        2.300000
# max       13.200000

# %% [markdown]
# ### Cleaning Data

# %% [markdown]
# #### Membersihkan Data Aotizhongxin_df

# %% [markdown]
# ##### Menghilangkan duplicate data

# %% [markdown]
# Pada data ini tidak terdapat duplicate data seperti yang telah ditampilkan pada tahap assessing data, namun akan tetap kita pastikan kembali tidak ada duplicate

# %%
# Menghilangkan duplicate data
Aotizhongxin_df.drop_duplicates(inplace=True)

# %% [markdown]
# Memastikan tidak ada duplicate data

# %%
print("Jumlah duplikasi: ", Aotizhongxin_df.duplicated().sum())
# Out:
# Jumlah duplikasi:  0

# %% [markdown]
# ##### Menangani missing value

# %% [markdown]
# Pada data ini terdapat missing value pada variabel PM2.5, PM10, SO2, NO2, CO, O3, TEMP, PRES, DEWP, RAIN, wd, dan WSPM.
#
# - Untuk variabel PM2.5, PM10, SO2, NO2, CO, dan O3 digunakan metode yang paling cocok yaitu interpolasi.
# - Untuk variabel TEMP, PRES, DEWP, RAIN, wd, dan WSPM digunakan metode yang paling cocok yaitu forward fill.

# %%
# Metode interpolasi
Aotizhongxin_df[['PM2.5', 'PM10', 'SO2', 'NO2', 'CO', 'O3']] = Aotizhongxin_df[['PM2.5', 'PM10', 'SO2', 'NO2', 'CO', 'O3']].interpolate(method='linear')

# Metode forward fill
Aotizhongxin_df[['TEMP', 'PRES', 'DEWP', 'RAIN', 'wd', 'WSPM']] = Aotizhongxin_df[['TEMP', 'PRES', 'DEWP', 'RAIN', 'wd', 'WSPM']].fillna(method='ffill')

# %% [markdown]
# Memastikan pembersihan missing value telah tersebut berhasil

# %%
Aotizhongxin_df.isna().sum()
# Out:
# No         0
# year       0
# month      0
# day        0
# hour       0
# PM2.5      0
# PM10       0
# SO2        0
# NO2        0
# CO         0
# O3         0
# TEMP       0
# PRES       0
# DEWP       0
# RAIN       0
# wd         0
# WSPM       0
# station    0
# dtype: int64

# %% [markdown]
# ##### Menangani inacurate value

# %% [markdown]
# Pada data ini tidak ditemukan keanehan pada ringkasan parameter statistiknya sehingga tidak diperlukan cleaning data untuk inacurate value

# %% [markdown]
# #### Membersihkan Data Changping_df

# %% [markdown]
# ##### Menghilangkan duplicate data

# %% [markdown]
# Pada data ini tidak terdapat duplicate data seperti yang telah ditampilkan pada tahap assessing data, namun akan tetap kita pastikan kembali tidak ada duplicate

# %%
# Menghilangkan duplicate data
Changping_df.drop_duplicates(inplace=True)

# %% [markdown]
# Memastikan tidak ada duplicate data

# %%
print("Jumlah duplikasi: ", Changping_df.duplicated().sum())
# Out:
# Jumlah duplikasi:  0

# %% [markdown]
# ##### Menangani missing value

# %% [markdown]
# Pada data ini terdapat missing value pada variabel PM2.5, PM10, SO2, NO2, CO, O3, TEMP, PRES, DEWP, RAIN, wd, dan WSPM.
#
# - Untuk variabel PM2.5, PM10, SO2, NO2, CO, dan O3 digunakan metode yang paling cocok yaitu interpolasi.
# - Untuk variabel TEMP, PRES, DEWP, RAIN, wd, dan WSPM digunakan metode yang paling cocok yaitu forward fill.

# %%
# Metode interpolasi
Changping_df[['PM2.5', 'PM10', 'SO2', 'NO2', 'CO', 'O3']] = Changping_df[['PM2.5', 'PM10', 'SO2', 'NO2', 'CO', 'O3']].interpolate(method='linear')

# Metode forward fill
Changping_df[['TEMP', 'PRES', 'DEWP', 'RAIN', 'wd', 'WSPM']] = Changping_df[['TEMP', 'PRES', 'DEWP', 'RAIN', 'wd', 'WSPM']].fillna(method='ffill')

# %% [markdown]
# Memastikan pembersihan missing value telah tersebut berhasil

# %%
Aotizhongxin_df.isna().sum()
# Out:
# No         0
# year       0
# month      0
# day        0
# hour       0
# PM2.5      0
# PM10       0
# SO2        0
# NO2        0
# CO         0
# O3         0
# TEMP       0
# PRES       0
# DEWP       0
# RAIN       0
# wd         0
# WSPM       0
# station    0
# dtype: int64

# %% [markdown]
# ##### Menangani inacurate value

# %% [markdown]
# Pada data ini tidak ditemukan keanehan pada ringkasan parameter statistiknya sehingga tidak diperlukan cleaning data untuk inacurate value

# %% [markdown]
# #### Membersihkan Data Dingling_df

# %% [markdown]
# ##### Menghilangkan duplicate data

# %% [markdown]
# Pada data ini tidak terdapat duplicate data seperti yang telah ditampilkan pada tahap assessing data, namun akan tetap kita pastikan kembali tidak ada duplicate

# %%
# Menghilangkan duplicate data
Dingling_df.drop_duplicates(inplace=True)

# %% [markdown]
# Memastikan tidak ada duplicate data

# %%
print("Jumlah duplikasi: ", Dingling_df.duplicated().sum())
# Out:
# Jumlah duplikasi:  0

# %% [markdown]
# ##### Menangani missing value

# %% [markdown]
# Pada data ini terdapat missing value pada variabel PM2.5, PM10, SO2, NO2, CO, O3, TEMP, PRES, DEWP, RAIN, wd, dan WSPM.
#
# - Untuk variabel PM2.5, PM10, SO2, NO2, CO, dan O3 digunakan metode yang paling cocok yaitu interpolasi.
# - Untuk variabel TEMP, PRES, DEWP, RAIN, wd, dan WSPM digunakan metode yang paling cocok yaitu forward fill.

# %%
# Metode interpolasi
Dingling_df[['PM2.5', 'PM10', 'SO2', 'NO2', 'CO', 'O3']] = Dingling_df[['PM2.5', 'PM10', 'SO2', 'NO2', 'CO', 'O3']].interpolate(method='linear')

# Metode forward fill
Dingling_df[['TEMP', 'PRES', 'DEWP', 'RAIN', 'wd', 'WSPM']] = Dingling_df[['TEMP', 'PRES', 'DEWP', 'RAIN', 'wd', 'WSPM']].fillna(method='ffill')

# %% [markdown]
# Memastikan pembersihan missing value telah tersebut berhasil

# %%
Aotizhongxin_df.isna().sum()
# Out:
# No         0
# year       0
# month      0
# day        0
# hour       0
# PM2.5      0
# PM10       0
# SO2        0
# NO2        0
# CO         0
# O3         0
# TEMP       0
# PRES       0
# DEWP       0
# RAIN       0
# wd         0
# WSPM       0
# station    0
# dtype: int64

# %% [markdown]
# ##### Menangani inacurate value

# %% [markdown]
# Pada data ini tidak ditemukan keanehan pada ringkasan parameter statistiknya sehingga tidak diperlukan cleaning data untuk inacurate value

# %% [markdown]
# #### Membersihkan Data Dongsi_df

# %% [markdown]
# ##### Menghilangkan duplicate data

# %% [markdown]
# Pada data ini tidak terdapat duplicate data seperti yang telah ditampilkan pada tahap assessing data, namun akan tetap kita pastikan kembali tidak ada duplicate

# %%
# Menghilangkan duplicate data
Dongsi_df.drop_duplicates(inplace=True)

# %% [markdown]
# Memastikan tidak ada duplicate data

# %%
print("Jumlah duplikasi: ", Dongsi_df.duplicated().sum())
# Out:
# Jumlah duplikasi:  0

# %% [markdown]
# ##### Menangani missing value

# %% [markdown]
# Pada data ini terdapat missing value pada variabel PM2.5, PM10, SO2, NO2, CO, O3, TEMP, PRES, DEWP, RAIN, wd, dan WSPM.
#
# - Untuk variabel PM2.5, PM10, SO2, NO2, CO, dan O3 digunakan metode yang paling cocok yaitu interpolasi.
# - Untuk variabel TEMP, PRES, DEWP, RAIN, wd, dan WSPM digunakan metode yang paling cocok yaitu forward fill.

# %%
# Metode interpolasi
Dongsi_df[['PM2.5', 'PM10', 'SO2', 'NO2', 'CO', 'O3']] = Dongsi_df[['PM2.5', 'PM10', 'SO2', 'NO2', 'CO', 'O3']].interpolate(method='linear')

# Metode forward fill
Dongsi_df[['TEMP', 'PRES', 'DEWP', 'RAIN', 'wd', 'WSPM']] = Dongsi_df[['TEMP', 'PRES', 'DEWP', 'RAIN', 'wd', 'WSPM']].fillna(method='ffill')

# %% [markdown]
# Memastikan pembersihan missing value telah tersebut berhasil

# %%
Dongsi_df.isna().sum()
# Out:
# No         0
# year       0
# month      0
# day        0
# hour       0
# PM2.5      0
# PM10       0
# SO2        0
# NO2        0
# CO         0
# O3         0
# TEMP       0
# PRES       0
# DEWP       0
# RAIN       0
# wd         0
# WSPM       0
# station    0
# dtype: int64

# %% [markdown]
# ##### Menangani inacurate value

# %% [markdown]
# Pada data ini tidak ditemukan keanehan pada ringkasan parameter statistiknya sehingga tidak diperlukan cleaning data untuk inacurate value

# %% [markdown]
# #### Membersihkan Data Guanyuan_df

# %% [markdown]
# ##### Menghilangkan duplicate data

# %% [markdown]
# Pada data ini tidak terdapat duplicate data seperti yang telah ditampilkan pada tahap assessing data, namun akan tetap kita pastikan kembali tidak ada duplicate

# %%
# Menghilangkan duplicate data
Guanyuan_df.drop_duplicates(inplace=True)

# %% [markdown]
# Memastikan tidak ada duplicate data

# %%
print("Jumlah duplikasi: ", Guanyuan_df.duplicated().sum())
# Out:
# Jumlah duplikasi:  0

# %% [markdown]
# ##### Menangani missing value

# %% [markdown]
# Pada data ini terdapat missing value pada variabel PM2.5, PM10, SO2, NO2, CO, O3, TEMP, PRES, DEWP, RAIN, wd, dan WSPM.
#
# - Untuk variabel PM2.5, PM10, SO2, NO2, CO, dan O3 digunakan metode yang paling cocok yaitu interpolasi.
# - Untuk variabel TEMP, PRES, DEWP, RAIN, wd, dan WSPM digunakan metode yang paling cocok yaitu forward fill.

# %%
# Metode interpolasi
Guanyuan_df[['PM2.5', 'PM10', 'SO2', 'NO2', 'CO', 'O3']] = Guanyuan_df[['PM2.5', 'PM10', 'SO2', 'NO2', 'CO', 'O3']].interpolate(method='linear')

# Metode forward fill
Guanyuan_df[['TEMP', 'PRES', 'DEWP', 'RAIN', 'wd', 'WSPM']] = Guanyuan_df[['TEMP', 'PRES', 'DEWP', 'RAIN', 'wd', 'WSPM']].fillna(method='ffill')

# %% [markdown]
# Memastikan pembersihan missing value telah tersebut berhasil

# %%
Guanyuan_df.isna().sum()
# Out:
# No         0
# year       0
# month      0
# day        0
# hour       0
# PM2.5      0
# PM10       0
# SO2        0
# NO2        0
# CO         0
# O3         0
# TEMP       0
# PRES       0
# DEWP       0
# RAIN       0
# wd         0
# WSPM       0
# station    0
# dtype: int64

# %% [markdown]
# ##### Menangani inacurate value

# %% [markdown]
# Pada data ini tidak ditemukan keanehan pada ringkasan parameter statistiknya sehingga tidak diperlukan cleaning data untuk inacurate value

# %% [markdown]
# #### Membersihkan Data Gucheng_df

# %% [markdown]
# ##### Menghilangkan duplicate data

# %% [markdown]
# Pada data ini tidak terdapat duplicate data seperti yang telah ditampilkan pada tahap assessing data, namun akan tetap kita pastikan kembali tidak ada duplicate

# %%
# Menghilangkan duplicate data
Gucheng_df.drop_duplicates(inplace=True)

# %% [markdown]
# Memastikan tidak ada duplicate data

# %%
print("Jumlah duplikasi: ", Gucheng_df.duplicated().sum())
# Out:
# Jumlah duplikasi:  0

# %% [markdown]
# ##### Menangani missing value

# %% [markdown]
# Pada data ini terdapat missing value pada variabel PM2.5, PM10, SO2, NO2, CO, O3, TEMP, PRES, DEWP, RAIN, wd, dan WSPM.
#
# - Untuk variabel PM2.5, PM10, SO2, CO, dan O3 digunakan metode yang paling cocok yaitu interpolasi.
# - Untuk variabel TEMP, PRES, DEWP, RAIN, wd, dan WSPM digunakan metode yang paling cocok yaitu forward fill.
# - Untuk variabel NO2 pada data ini dilakukan backward fill karena terdapat missing value pada awal data yang membuatnya tidak dapat digunakan metode interpolasi.

# %%
# Metode interpolasi
Gucheng_df[['PM2.5', 'PM10', 'SO2', 'NO2', 'CO', 'O3']] = Gucheng_df[['PM2.5', 'PM10', 'SO2', 'NO2', 'CO', 'O3']].interpolate(method='linear')

# Metode forward fill
Gucheng_df[['TEMP', 'PRES', 'DEWP', 'RAIN', 'wd', 'WSPM']] = Gucheng_df[['TEMP', 'PRES', 'DEWP', 'RAIN', 'wd', 'WSPM']].fillna(method='ffill')

# Metode backward fill
Gucheng_df[['NO2']] = Gucheng_df[['NO2']].fillna(method='bfill')

# %% [markdown]
# Memastikan pembersihan missing value telah tersebut berhasil

# %%
Gucheng_df.isna().sum()
# Out:
# No         0
# year       0
# month      0
# day        0
# hour       0
# PM2.5      0
# PM10       0
# SO2        0
# NO2        0
# CO         0
# O3         0
# TEMP       0
# PRES       0
# DEWP       0
# RAIN       0
# wd         0
# WSPM       0
# station    0
# dtype: int64

# %% [markdown]
# ##### Menangani inacurate value

# %% [markdown]
# Pada data ini tidak ditemukan keanehan pada ringkasan parameter statistiknya sehingga tidak diperlukan cleaning data untuk inacurate value

# %% [markdown]
# #### Membersihkan Data Huairou_df

# %% [markdown]
# ##### Menghilangkan duplicate data

# %% [markdown]
# Pada data ini tidak terdapat duplicate data seperti yang telah ditampilkan pada tahap assessing data, namun akan tetap kita pastikan kembali tidak ada duplicate

# %%
# Menghilangkan duplicate data
Huairou_df.drop_duplicates(inplace=True)

# %% [markdown]
# Memastikan tidak ada duplicate data

# %%
print("Jumlah duplikasi: ", Huairou_df.duplicated().sum())
# Out:
# Jumlah duplikasi:  0

# %% [markdown]
# ##### Menangani missing value

# %% [markdown]
# Pada data ini terdapat missing value pada variabel PM2.5, PM10, SO2, NO2, CO, O3, TEMP, PRES, DEWP, RAIN, wd, dan WSPM.
#
# - Untuk variabel PM2.5, PM10, SO2, NO2, CO, dan O3 digunakan metode yang paling cocok yaitu interpolasi.
# - Untuk variabel TEMP, PRES, DEWP, RAIN, wd, dan WSPM digunakan metode yang paling cocok yaitu forward fill.

# %%
# Metode interpolasi
Huairou_df[['PM2.5', 'PM10', 'SO2', 'NO2', 'CO', 'O3']] = Huairou_df[['PM2.5', 'PM10', 'SO2', 'NO2', 'CO', 'O3']].interpolate(method='linear')

# Metode forward fill
Huairou_df[['TEMP', 'PRES', 'DEWP', 'RAIN', 'wd', 'WSPM']] = Huairou_df[['TEMP', 'PRES', 'DEWP', 'RAIN', 'wd', 'WSPM']].fillna(method='ffill')

# %% [markdown]
# Memastikan pembersihan missing value telah tersebut berhasil

# %%
Guanyuan_df.isna().sum()
# Out:
# No         0
# year       0
# month      0
# day        0
# hour       0
# PM2.5      0
# PM10       0
# SO2        0
# NO2        0
# CO         0
# O3         0
# TEMP       0
# PRES       0
# DEWP       0
# RAIN       0
# wd         0
# WSPM       0
# station    0
# dtype: int64

# %% [markdown]
# ##### Menangani inacurate value

# %% [markdown]
# Pada data ini tidak ditemukan keanehan pada ringkasan parameter statistiknya sehingga tidak diperlukan cleaning data untuk inacurate value

# %% [markdown]
# #### Membersihkan Data Nongzhanguan_df

# %% [markdown]
# ##### Menghilangkan duplicate data

# %% [markdown]
# Pada data ini tidak terdapat duplicate data seperti yang telah ditampilkan pada tahap assessing data, namun akan tetap kita pastikan kembali tidak ada duplicate

# %%
# Menghilangkan duplicate data
Nongzhanguan_df.drop_duplicates(inplace=True)

# %% [markdown]
# Memastikan tidak ada duplicate data

# %%
print("Jumlah duplikasi: ", Nongzhanguan_df.duplicated().sum())
# Out:
# Jumlah duplikasi:  0

# %% [markdown]
# ##### Menangani missing value

# %% [markdown]
# Pada data ini terdapat missing value pada variabel PM2.5, PM10, SO2, NO2, CO, O3, TEMP, PRES, DEWP, RAIN, wd, dan WSPM.
#
# - Untuk variabel PM2.5, PM10, SO2, NO2, CO, dan O3 digunakan metode yang paling cocok yaitu interpolasi.
# - Untuk variabel TEMP, PRES, DEWP, RAIN, wd, dan WSPM digunakan metode yang paling cocok yaitu forward fill.

# %%
# Metode interpolasi
Nongzhanguan_df[['PM2.5', 'PM10', 'SO2', 'NO2', 'CO', 'O3']] = Nongzhanguan_df[['PM2.5', 'PM10', 'SO2', 'NO2', 'CO', 'O3']].interpolate(method='linear')

# Metode forward fill
Nongzhanguan_df[['TEMP', 'PRES', 'DEWP', 'RAIN', 'wd', 'WSPM']] = Nongzhanguan_df[['TEMP', 'PRES', 'DEWP', 'RAIN', 'wd', 'WSPM']].fillna(method='ffill')

# %% [markdown]
# Memastikan pembersihan missing value telah tersebut berhasil

# %%
Nongzhanguan_df.isna().sum()
# Out:
# No         0
# year       0
# month      0
# day        0
# hour       0
# PM2.5      0
# PM10       0
# SO2        0
# NO2        0
# CO         0
# O3         0
# TEMP       0
# PRES       0
# DEWP       0
# RAIN       0
# wd         0
# WSPM       0
# station    0
# dtype: int64

# %% [markdown]
# ##### Menangani inacurate value

# %% [markdown]
# Pada data ini tidak ditemukan keanehan pada ringkasan parameter statistiknya sehingga tidak diperlukan cleaning data untuk inacurate value

# %% [markdown]
# #### Membersihkan Data Shunyi_df

# %% [markdown]
# ##### Menghilangkan duplicate data

# %% [markdown]
# Pada data ini tidak terdapat duplicate data seperti yang telah ditampilkan pada tahap assessing data, namun akan tetap kita pastikan kembali tidak ada duplicate

# %%
# Menghilangkan duplicate data
Shunyi_df.drop_duplicates(inplace=True)

# %% [markdown]
# Memastikan tidak ada duplicate data

# %%
print("Jumlah duplikasi: ", Shunyi_df.duplicated().sum())
# Out:
# Jumlah duplikasi:  0

# %% [markdown]
# ##### Menangani missing value

# %% [markdown]
# Pada data ini terdapat missing value pada variabel PM2.5, PM10, SO2, NO2, CO, O3, TEMP, PRES, DEWP, RAIN, wd, dan WSPM.
#
# - Untuk variabel PM2.5, PM10, SO2, NO2, CO, dan O3 digunakan metode yang paling cocok yaitu interpolasi.
# - Untuk variabel TEMP, PRES, DEWP, RAIN, wd, dan WSPM digunakan metode yang paling cocok yaitu forward fill.

# %%
# Metode interpolasi
Shunyi_df[['PM2.5', 'PM10', 'SO2', 'NO2', 'CO', 'O3']] = Shunyi_df[['PM2.5', 'PM10', 'SO2', 'NO2', 'CO', 'O3']].interpolate(method='linear')

# Metode forward fill
Shunyi_df[['TEMP', 'PRES', 'DEWP', 'RAIN', 'wd', 'WSPM']] = Shunyi_df[['TEMP', 'PRES', 'DEWP', 'RAIN', 'wd', 'WSPM']].fillna(method='ffill')

# %% [markdown]
# Memastikan pembersihan missing value telah tersebut berhasil

# %%
Shunyi_df.isna().sum()
# Out:
# No         0
# year       0
# month      0
# day        0
# hour       0
# PM2.5      0
# PM10       0
# SO2        0
# NO2        0
# CO         0
# O3         0
# TEMP       0
# PRES       0
# DEWP       0
# RAIN       0
# wd         0
# WSPM       0
# station    0
# dtype: int64

# %% [markdown]
# ##### Menangani inacurate value

# %% [markdown]
# Pada data ini tidak ditemukan keanehan pada ringkasan parameter statistiknya sehingga tidak diperlukan cleaning data untuk inacurate value

# %% [markdown]
# #### Membersihkan Data Tiantan_df

# %% [markdown]
# ##### Menghilangkan duplicate data

# %% [markdown]
# Pada data ini tidak terdapat duplicate data seperti yang telah ditampilkan pada tahap assessing data, namun akan tetap kita pastikan kembali tidak ada duplicate

# %%
# Menghilangkan duplicate data
Tiantan_df.drop_duplicates(inplace=True)

# %% [markdown]
# Memastikan tidak ada duplicate data

# %%
print("Jumlah duplikasi: ", Tiantan_df.duplicated().sum())
# Out:
# Jumlah duplikasi:  0

# %% [markdown]
# ##### Menangani missing value

# %% [markdown]
# Pada data ini terdapat missing value pada variabel PM2.5, PM10, SO2, NO2, CO, O3, TEMP, PRES, DEWP, RAIN, wd, dan WSPM.
#
# - Untuk variabel PM2.5, PM10, SO2, NO2, CO, dan O3 digunakan metode yang paling cocok yaitu interpolasi.
# - Untuk variabel TEMP, PRES, DEWP, RAIN, wd, dan WSPM digunakan metode yang paling cocok yaitu forward fill.

# %%
# Metode interpolasi
Tiantan_df[['PM2.5', 'PM10', 'SO2', 'NO2', 'CO', 'O3']] = Tiantan_df[['PM2.5', 'PM10', 'SO2', 'NO2', 'CO', 'O3']].interpolate(method='linear')

# Metode forward fill
Tiantan_df[['TEMP', 'PRES', 'DEWP', 'RAIN', 'wd', 'WSPM']] = Tiantan_df[['TEMP', 'PRES', 'DEWP', 'RAIN', 'wd', 'WSPM']].fillna(method='ffill')

# %% [markdown]
# Memastikan pembersihan missing value telah tersebut berhasil

# %%
Tiantan_df.isna().sum()
# Out:
# No         0
# year       0
# month      0
# day        0
# hour       0
# PM2.5      0
# PM10       0
# SO2        0
# NO2        0
# CO         0
# O3         0
# TEMP       0
# PRES       0
# DEWP       0
# RAIN       0
# wd         0
# WSPM       0
# station    0
# dtype: int64

# %% [markdown]
# ##### Menangani inacurate value

# %% [markdown]
# Pada data ini tidak ditemukan keanehan pada ringkasan parameter statistiknya sehingga tidak diperlukan cleaning data untuk inacurate value

# %% [markdown]
# #### Membersihkan Data Wanliu_df

# %% [markdown]
# ##### Menghilangkan duplicate data

# %% [markdown]
# Pada data ini tidak terdapat duplicate data seperti yang telah ditampilkan pada tahap assessing data, namun akan tetap kita pastikan kembali tidak ada duplicate

# %%
# Menghilangkan duplicate data
Wanliu_df.drop_duplicates(inplace=True)

# %% [markdown]
# Memastikan tidak ada duplicate data

# %%
print("Jumlah duplikasi: ", Wanliu_df.duplicated().sum())
# Out:
# Jumlah duplikasi:  0

# %% [markdown]
# ##### Menangani missing value

# %% [markdown]
# Pada data ini terdapat missing value pada variabel PM2.5, PM10, SO2, NO2, CO, O3, TEMP, PRES, DEWP, RAIN, wd, dan WSPM.
#
# - Untuk variabel PM2.5, PM10, SO2, NO2, CO, dan O3 digunakan metode yang paling cocok yaitu interpolasi.
# - Untuk variabel TEMP, PRES, DEWP, RAIN, wd, dan WSPM digunakan metode yang paling cocok yaitu forward fill.

# %%
# Metode interpolasi
Wanliu_df[['PM2.5', 'PM10', 'SO2', 'NO2', 'CO', 'O3']] = Wanliu_df[['PM2.5', 'PM10', 'SO2', 'NO2', 'CO', 'O3']].interpolate(method='linear')

# Metode forward fill
Wanliu_df[['TEMP', 'PRES', 'DEWP', 'RAIN', 'wd', 'WSPM']] = Wanliu_df[['TEMP', 'PRES', 'DEWP', 'RAIN', 'wd', 'WSPM']].fillna(method='ffill')

# %% [markdown]
# Memastikan pembersihan missing value telah tersebut berhasil

# %%
Wanliu_df.isna().sum()
# Out:
# No         0
# year       0
# month      0
# day        0
# hour       0
# PM2.5      0
# PM10       0
# SO2        0
# NO2        0
# CO         0
# O3         0
# TEMP       0
# PRES       0
# DEWP       0
# RAIN       0
# wd         0
# WSPM       0
# station    0
# dtype: int64

# %% [markdown]
# ##### Menangani inacurate value

# %% [markdown]
# Pada data ini tidak ditemukan keanehan pada ringkasan parameter statistiknya sehingga tidak diperlukan cleaning data untuk inacurate value

# %% [markdown]
# #### Membersihkan Data Wanshouxigong_df

# %% [markdown]
# ##### Menghilangkan duplicate data

# %% [markdown]
# Pada data ini tidak terdapat duplicate data seperti yang telah ditampilkan pada tahap assessing data, namun akan tetap kita pastikan kembali tidak ada duplicate

# %%
# Menghilangkan duplicate data
Wanshouxigong_df.drop_duplicates(inplace=True)

# %% [markdown]
# Memastikan tidak ada duplicate data

# %%
print("Jumlah duplikasi: ", Wanshouxigong_df.duplicated().sum())
# Out:
# Jumlah duplikasi:  0

# %% [markdown]
# ##### Menangani missing value

# %% [markdown]
# Pada data ini terdapat missing value pada variabel PM2.5, PM10, SO2, NO2, CO, O3, TEMP, PRES, DEWP, RAIN, wd, dan WSPM.
#
# - Untuk variabel PM2.5, PM10, SO2, NO2, CO, dan O3 digunakan metode yang paling cocok yaitu interpolasi.
# - Untuk variabel TEMP, PRES, DEWP, RAIN, wd, dan WSPM digunakan metode yang paling cocok yaitu forward fill.

# %%
# Metode interpolasi
Wanshouxigong_df[['PM2.5', 'PM10', 'SO2', 'NO2', 'CO', 'O3']] = Wanshouxigong_df[['PM2.5', 'PM10', 'SO2', 'NO2', 'CO', 'O3']].interpolate(method='linear')

# Metode forward fill
Wanshouxigong_df[['TEMP', 'PRES', 'DEWP', 'RAIN', 'wd', 'WSPM']] = Wanshouxigong_df[['TEMP', 'PRES', 'DEWP', 'RAIN', 'wd', 'WSPM']].fillna(method='ffill')

# %% [markdown]
# Memastikan pembersihan missing value telah tersebut berhasil

# %%
Wanshouxigong_df.isna().sum()
# Out:
# No         0
# year       0
# month      0
# day        0
# hour       0
# PM2.5      0
# PM10       0
# SO2        0
# NO2        0
# CO         0
# O3         0
# TEMP       0
# PRES       0
# DEWP       0
# RAIN       0
# wd         0
# WSPM       0
# station    0
# dtype: int64

# %% [markdown]
# ##### Menangani inacurate value

# %% [markdown]
# Pada data ini tidak ditemukan keanehan pada ringkasan parameter statistiknya sehingga tidak diperlukan cleaning data untuk inacurate value

# %% [markdown]
# ## Exploratory Data Analysis (EDA)

# %% [markdown]
# ### Explore Data all_df

# %% [markdown]
# #### Penggabungan seluruh DataFrame

# %% [markdown]
# Proses ini dilakukan untuk mempermudah tahapan analisis

# %% [markdown]
# ##### Penggabungan dataframe

# %%
# List semua dataframe
list_df = [Aotizhongxin_df, Changping_df, Dingling_df, Dongsi_df, Guanyuan_df, Gucheng_df, Huairou_df, Nongzhanguan_df, Shunyi_df, Tiantan_df, Wanliu_df, Wanshouxigong_df]

# Gabungkan semua dataframe
all_df = pd.concat(list_df, ignore_index=True)

# %% [markdown]
# ##### Gathering data

# %% [markdown]
# Load tabel all_df

# %%
all_df.head()
# Out:
#    No  year  month  day  hour  PM2.5  PM10   SO2   NO2     CO    O3  TEMP  \
# 0   1  2013      3    1     0    4.0   4.0   4.0   7.0  300.0  77.0  -0.7
# 1   2  2013      3    1     1    8.0   8.0   4.0   7.0  300.0  77.0  -1.1
# 2   3  2013      3    1     2    7.0   7.0   5.0  10.0  300.0  73.0  -1.1
# 3   4  2013      3    1     3    6.0   6.0  11.0  11.0  300.0  72.0  -1.4
# 4   5  2013      3    1     4    3.0   3.0  12.0  12.0  300.0  72.0  -2.0
#
#      PRES  DEWP  RAIN   wd  WSPM       station
# 0  1023.0 -18.8   0.0  NNW   4.4  Aotizhongxin
# 1  1023.2 -18.2   0.0    N   4.7  Aotizhongxin
# 2  1023.5 -18.2   0.0  NNW   5.6  Aotizhongxin
# 3  1024.5 -19.4   0.0   NW   3.1  Aotizhongxin
# 4  1025.2 -19.5   0.0    N   2.0  Aotizhongxin

# %% [markdown]
# ##### Assessing data

# %% [markdown]
# Pengecekan missing value

# %%
all_df.isna().sum()
# Out:
# No         0
# year       0
# month      0
# day        0
# hour       0
# PM2.5      0
# PM10       0
# SO2        0
# NO2        2
# CO         0
# O3         0
# TEMP       0
# PRES       0
# DEWP       0
# RAIN       0
# wd         0
# WSPM       0
# station    0
# dtype: int64

# %% [markdown]
# Pengecekan duplikasi data dan ringkasan parameter statistik

# %%
print("Jumlah duplikasi: ",all_df.duplicated().sum())

all_df.describe()
# Out:
# Jumlah duplikasi:  0
#                   No           year          month            day  \
# count  420768.000000  420768.000000  420768.000000  420768.000000
# mean    17532.500000    2014.662560       6.522930      15.729637
# std     10122.116943       1.177198       3.448707       8.800102
# min         1.000000    2013.000000       1.000000       1.000000
# 25%      8766.750000    2014.000000       4.000000       8.000000
# 50%     17532.500000    2015.000000       7.000000      16.000000
# 75%     26298.250000    2016.000000      10.000000      23.000000
# max     35064.000000    2017.000000      12.000000      31.000000
#
#                 hour          PM2.5           PM10            SO2  \
# count  420768.000000  420768.000000  420768.000000  420768.000000
# mean       11.500000      79.839718     104.910268      15.913090
# std         6.922195      80.950217      92.431422      21.896609
# min         0.000000       2.000000       2.000000       0.285600
# 25%         5.750000      20.000000      36.000000       3.000000
# 50%        11.500000      55.000000      82.000000       7.000000
# 75%        17.250000     111.000000     145.000000      20.000000
# max        23.000000     999.000000     999.000000     500.000000
#
#                  NO2             CO             O3           TEMP  \
# count  420766.000000  420768.000000  420768.000000  420768.000000
# mean       50.599249    1235.682649      57.237872      13.531801
# std        35.171845    1161.790893      57.135195      11.438422
# min         1.026500     100.000000       0.214200     -19.900000
# 25%        23.000000     500.000000      10.000000       3.100000
# 50%        43.000000     900.000000      44.000000      14.500000
# 75%        71.000000    1500.000000      82.000000      23.300000
# max       290.000000   10000.000000    1071.000000      41.600000
#
#                 PRES           DEWP           RAIN           WSPM
# count  420768.000000  420768.000000  420768.000000  420768.000000
# mean     1010.753501       2.482413       0.064436       1.729789
# std        10.474728      13.797889       0.820661       1.246571
# min       982.400000     -43.400000       0.000000       0.000000
# 25%      1002.300000      -8.900000       0.000000       0.900000
# 50%      1010.400000       3.000000       0.000000       1.400000
# 75%      1019.000000      15.100000       0.000000       2.200000
# max      1042.800000      29.100000      72.500000      13.200000

# %% [markdown]
# ##### Cleaning data

# %% [markdown]
# DataFrame all_df memiliki missing value pada variabel 'NO2' dan 'time'. Sama seperti sebelumnya, 'NO2' akan menggunakan metode interpolasi, sedangkan 'time' merupakan variabel baru yang muncul setelah dataframe digabungkan dan tidak akan digunakan dalam proses selanjutnya maka 'time' dapat diabaikan.

# %%
# Metode interpolasi
all_df[['NO2']] = all_df[['NO2']].interpolate(method='linear')

# %% [markdown]
# Pengecekan missing value

# %%
all_df.isna().sum()
# Out:
# No         0
# year       0
# month      0
# day        0
# hour       0
# PM2.5      0
# PM10       0
# SO2        0
# NO2        0
# CO         0
# O3         0
# TEMP       0
# PRES       0
# DEWP       0
# RAIN       0
# wd         0
# WSPM       0
# station    0
# dtype: int64

# %% [markdown]
# #### Explore variabel polutan dan stasiun

# %%
# Mendefinisikan variabel
pollutants = ['PM2.5', 'PM10', 'SO2', 'NO2', 'CO', 'O3']
stations = ['Dongsi', 'Guanyuan', 'Gucheng', 'Huairou', 'Nongzhanguan', 'Shunyi', 'Tiantan', 'Wanliu', 'Wanshouxigong']

# Memuat pivot table dengan 'station' sebagai indeks dan rata-rata untuk setiap polutan
pivot_table = all_df.pivot_table(index='station', values=pollutants, aggfunc='mean')

print(pivot_table)
# Out:
#                         CO        NO2         O3        PM10      PM2.5  \
# station
# Aotizhongxin   1264.692405  59.074106  55.328626  110.210033  82.540623
# Changping      1156.990246  44.206153  57.976253   94.788575  70.986438
# Dingling        925.111838  27.304331  70.530792   84.113713  66.845557
# Dongsi         1331.913045  53.953078  57.700357  110.347617  86.144243
# Guanyuan       1258.327045  58.139298  54.817142  109.372349  82.897522
# Gucheng        1338.100060  55.822315  58.000001  119.261567  84.074802
# Huairou        1019.671871  32.077275  60.872173   92.422670  69.501747
# Nongzhanguan   1327.767611  58.095053  58.432876  109.384022  85.079472
# Shunyi         1197.904660  44.094695  54.218810   99.271936  79.437962
# Tiantan        1305.333262  53.258828  56.148077  106.537076  82.033097
# Wanliu         1328.761180  65.668418  46.909375  110.707858  83.467612
# Wanshouxigong  1373.618569  55.495402  55.919979  112.505795  85.067548
#
#                      SO2
# station
# Aotizhongxin   17.459251
# Changping      14.943066
# Dingling       11.797849
# Dongsi         18.506142
# Guanyuan       17.609312
# Gucheng        15.705821
# Huairou        12.446681
# Nongzhanguan   18.760102
# Shunyi         13.445971
# Tiantan        14.510018
# Wanliu         18.409514
# Wanshouxigong  17.363354

# %% [markdown]
# #### Explore variabel lingkungan dan polutan

# %% [markdown]
# Analisis ini dilakukan untuk mengetahui hubungan antara variabel polutan ('PM2.5', 'PM10', 'SO2', 'NO2', 'CO', 'O3') dengan variabel lingkungan ('TEMP', 'PRES', 'DEWP', 'RAIN', 'wd', 'WSPM'). Output dari analisis ini dapat digunakan untuk mengetahui korelasi antar variabel.

# %%
# Mendefinisikan variabel
pollutants = ['PM2.5', 'PM10', 'SO2', 'NO2', 'CO', 'O3']
environmental_conditions = ['TEMP', 'PRES', 'DEWP', 'RAIN', 'wd', 'WSPM']

# Buat pivot table dengan 'environmental_conditions' sebagai indeks dan rata-rata untuk setiap polutan
pivot_table = all_df.pivot_table(index=environmental_conditions, values=pollutants, aggfunc='mean')

print(pivot_table)
# Out:
#                                           CO        NO2          O3  \
# TEMP  PRES   DEWP  RAIN wd  WSPM
# -19.9 1033.6 -28.6 0.0  NNE 1.0   300.000000   4.000000   44.000000
# -19.7 1034.3 -28.4 0.0  WSW 0.8   400.000000   6.000000   44.000000
# -19.5 1033.8 -28.7 0.0  NW  1.4   400.000000   7.000000   42.000000
# -18.9 1034.8 -30.3 0.0  NE  1.1   300.000000   2.000000   46.000000
# -18.7 1032.9 -28.7 0.0  SE  1.0   700.000000  20.000000   29.000000
# ...                                      ...        ...         ...
#  40.9 989.1   3.3  0.0  WNW 1.4   400.000000  30.000000  199.000000
#  41.0 987.9  -1.6  0.0  NNW 2.7   150.000000   9.000000  140.500000
#  41.1 992.3   1.9  0.0  NW  4.2   366.666667  32.353448  211.666667
#  41.4 987.5   0.5  0.0  NW  3.3   150.000000  10.000000  147.500000
#  41.6 988.7   3.8  0.0  W   3.3   200.000000  22.000000  132.000000
#
#                                        PM10      PM2.5     SO2
# TEMP  PRES   DEWP  RAIN wd  WSPM
# -19.9 1033.6 -28.6 0.0  NNE 1.0   23.000000   4.000000  2.0000
# -19.7 1034.3 -28.4 0.0  WSW 0.8    7.000000   7.000000  2.0000
# -19.5 1033.8 -28.7 0.0  NW  1.4   10.000000   8.000000  2.0000
# -18.9 1034.8 -30.3 0.0  NE  1.1   11.000000   6.000000  2.0000
# -18.7 1032.9 -28.7 0.0  SE  1.0   32.000000  10.000000  4.0000
# ...                                     ...        ...     ...
#  40.9 989.1   3.3  0.0  WNW 1.4   50.000000  12.000000  5.0000
#  41.0 987.9  -1.6  0.0  NNW 2.7   31.000000  18.500000  5.5000
#  41.1 992.3   1.9  0.0  NW  4.2   40.166667  23.666667  6.6623
#  41.4 987.5   0.5  0.0  NW  3.3   26.500000  18.000000  7.5000
#  41.6 988.7   3.8  0.0  W   3.3   51.000000  21.000000  3.0000
#
# [228365 rows x 6 columns]

# %% [markdown]
# #### Explore variabel polutan dan waktu (tahun)

# %% [markdown]
# Analisis ini dilakukan untuk mengetahui hubungan antara variabel polutan ('PM2.5', 'PM10', 'SO2', 'NO2', 'CO', 'O3') dengan variabel waktu khususnya tahun. Output dari analisis ini dapat digunakan untuk mengetahui tingkat polutan dalam sepanjang waktu.

# %%
# Mendefinisikan variabel
pollutants = ['PM2.5', 'PM10', 'SO2', 'NO2', 'CO', 'O3']

# Buat pivot table dengan 'tahun' sebagai indeks dan rata-rata untuk setiap polutan
pivot_table = all_df.pivot_table(index='year', values=pollutants, aggfunc='mean')

print(pivot_table)
# Out:
#                CO        NO2         O3        PM10      PM2.5        SO2
# year
# 2013  1205.307246  52.047859  56.258593  103.199397  79.768553  19.998777
# 2014  1271.124746  55.047965  57.901362  116.821115  86.183671  21.204405
# 2015  1261.916540  48.315936  59.290400  103.655023  79.306423  12.996102
# 2016  1138.022256  46.161344  58.134273   94.751717  72.078419   9.775876
# 2017  1617.493526  57.215837  39.953625  110.880797  92.407898  18.105815

# %% [markdown]
# #### Explore variabel waktu dan stasiun

# %% [markdown]
# Analisis ini dilakukan untuk mengetahui hubungan antara variabel polutan ('PM2.5', 'PM10', 'SO2', 'NO2', 'CO', 'O3') dengan variabel station ('Dongsi', 'Guanyuan', 'Gucheng', 'Huairou', 'Nongzhanguan', 'Shunyi', 'Tiantan', 'Wanliu', 'Wanshouxigong'). Output dari analisis ini dapat digunakan untuk mengetahui tingkat polutan di tiap stasiun serta melihat grafiknya berdasarkan waktu.

# %%
# Mendifinisikan variabel
pollutants = ['PM2.5', 'PM10', 'SO2', 'NO2', 'CO', 'O3']
stations = ['Dongsi', 'Guanyuan', 'Gucheng', 'Huairou', 'Nongzhanguan', 'Shunyi', 'Tiantan', 'Wanliu', 'Wanshouxigong']

# Buat pivot table dengan 'tahun' dan 'stasiun' sebagai indeks dan rata-rata untuk setiap polutan
pivot_table = all_df.pivot_table(index=['year', 'station'], values=pollutants, aggfunc='mean')

print(pivot_table)
# Out:
#                              CO        NO2         O3        PM10       PM2.5  \
# year station
# 2013 Aotizhongxin   1163.919458  63.355500  47.206555  112.940836   82.439202
#      Changping      1022.978758  40.960527  61.132385   91.176675   72.393246
#      Dingling        940.035607  28.772379  64.549386   78.884940   65.200980
#      Dongsi         1324.754766  57.327243  64.394874  104.619213   86.814474
#      Guanyuan       1132.745030  58.866182  54.120639  108.949074   81.651893
#      Gucheng        1341.740264  61.360784  55.781492  112.558211   81.498298
#      Huairou         988.408837  35.076202  64.256573   98.509191   68.619145
#      Nongzhanguan   1294.818015  59.518205  56.011564  103.735090   84.377996
#      Shunyi         1241.772740  41.665004  55.851085   95.145084   75.746460
#      Tiantan        1311.649714  53.174606  55.159147  108.312704   83.210172
#      Wanliu         1289.628540  68.547606  43.981046  112.366694   91.486179
#      Wanshouxigong  1411.235226  55.950066  52.658367  111.195057   83.784586
# 2014 Aotizhongxin   1186.718037  63.164053  48.594041  122.282112   89.747603
#      Changping      1229.971461  45.968002  63.019235  107.611416   79.881998
#      Dingling        890.734399  27.365046  72.762681   91.554865   75.643006
#      Dongsi         1379.931507  57.451142  56.930742  117.451986   87.979304
#      Guanyuan       1362.357306  64.343179  54.682477  116.123402   88.527374
#      Gucheng        1442.163242  62.424463  60.253139  134.781427   90.549121
#      Huairou        1070.981735  37.039566  68.108750   99.877363   77.143487
#      Nongzhanguan   1353.613014  62.296895  59.284635  127.224053   91.998082
#      Shunyi         1173.173516  46.826393  57.899463  111.620913   85.190993
#      Tiantan        1338.590183  56.159241  56.664224  114.889526   86.689874
#      Wanliu         1383.002283  75.740034  40.173148  131.279212   90.371107
#      Wanshouxigong  1442.260274  61.797568  56.443813  127.157100   90.482100
# 2015 Aotizhongxin   1436.889269  60.939047  63.604132  112.176747   81.831724
#      Changping      1162.431507  42.725942  58.307374   93.275696   68.832608
#      Dingling        963.934551  26.821221  71.166486   85.374616   64.353124
#      Dongsi         1338.498858  50.321912  55.875063  112.116832   87.128659
#      Guanyuan       1313.704338  54.921958  56.842614  106.321067   82.130183
#      Gucheng        1323.144977  49.588271  60.779538  116.366929   83.685051
#      Huairou        1038.784247  28.316707  60.640691   90.165559   70.500148
#      Nongzhanguan   1382.773973  58.249709  61.365702  106.989172   85.178584
#      Shunyi         1188.407534  43.097306  51.667546  100.412780   81.456119
#      Tiantan        1302.374429  52.020753  60.362877  102.863676   82.076450
#      Wanliu         1327.825342  60.059030  51.621204  106.598225   80.228191
#      Wanshouxigong  1364.229452  52.729372  59.251575  111.198973   84.276233
# 2016 Aotizhongxin   1190.215164  48.402493  61.854793   94.445811   74.236680
#      Changping      1129.764344  45.541268  54.002618   86.632115   61.665699
#      Dingling        870.810565  25.375114  75.364925   80.707707   61.701218
#      Dongsi         1236.429872  50.630009  57.578267  102.829064   80.180556
#      Guanyuan       1168.169399  53.459984  54.976719  104.927026   77.132514
#      Gucheng        1170.952869  49.777265  59.522883  111.118511   77.437443
#      Huairou         927.977004  27.278632  53.353256   82.266280   60.919627
#      Nongzhanguan   1209.369308  52.538764  60.216018   97.046790   76.096539
#      Shunyi         1099.948770  42.540642  53.700421   88.047245   72.223588
#      Tiantan        1196.163479  49.948657  55.540927   97.271232   73.801116
#      Wanliu         1232.388434  58.260189  53.182036   92.913536   71.433117
#      Wanshouxigong  1224.077869  50.183117  58.318420   98.815289   78.112933
# 2017 Aotizhongxin   1666.454802  66.229520  47.436088  106.988347   94.379237
#      Changping      1535.769774  51.014831  33.010593   94.150777   79.802966
#      Dingling       1157.062147  34.271186  53.824859   78.526483   68.281780
#      Dongsi         1623.552260  57.890890  39.790254  131.802260  102.220692
#      Guanyuan       1482.768362  64.920904  45.742232  116.255297   95.038842
#      Gucheng        1804.837571  62.319915  28.924788  126.437500  100.969986
#      Huairou        1314.971751  38.856992  46.625353   91.704802   73.865819
#      Nongzhanguan   1732.944915  58.230579  36.516243  119.663842  101.027542
#      Shunyi         1789.795198  55.607345  41.981992  106.852754   95.261299
#      Tiantan        1762.358757  63.945975  35.775777  125.860876   97.917373
#      Wanliu         1799.788136  69.086511  35.709040  110.650071   93.866879
#      Wanshouxigong  1739.618644  64.215395  34.106285  121.676554  106.262359
#
#                           SO2
# year station
# 2013 Aotizhongxin   23.599799
#      Changping      19.134785
#      Dingling       13.955578
#      Dongsi         23.705583
#      Guanyuan       21.859392
#      Gucheng        17.508021
#      Huairou        18.295972
#      Nongzhanguan   23.243093
#      Shunyi         15.083344
#      Tiantan        18.202909
#      Wanliu         23.615828
#      Wanshouxigong  21.781023
# 2014 Aotizhongxin   21.515582
#      Changping      21.250228
#      Dingling       14.872983
#      Dongsi         24.209064
#      Guanyuan       23.133562
#      Gucheng        21.290103
#      Huairou        17.582237
#      Nongzhanguan   24.876495
#      Shunyi         17.699406
#      Tiantan        19.771678
#      Wanliu         25.061336
#      Wanshouxigong  23.190183
# 2015 Aotizhongxin   14.354195
#      Changping      11.698721
#      Dingling       11.322508
#      Dongsi         15.202015
#      Guanyuan       14.073579
#      Gucheng        13.338265
#      Huairou         8.662831
#      Nongzhanguan   15.809857
#      Shunyi         10.454298
#      Tiantan        11.804817
#      Wanliu         14.847175
#      Wanshouxigong  14.384966
# 2016 Aotizhongxin   10.833732
#      Changping       8.144126
#      Dingling        7.166041
#      Dongsi         11.467327
#      Guanyuan       11.484517
#      Gucheng        10.204121
#      Huairou         6.638092
#      Nongzhanguan   11.556865
#      Shunyi          9.566541
#      Tiantan         8.946949
#      Wanliu         10.666724
#      Wanshouxigong  10.635474
# 2017 Aotizhongxin   20.827331
#      Changping      16.431497
#      Dingling       13.256356
#      Dongsi         20.364054
#      Guanyuan       21.259181
#      Gucheng        20.587924
#      Huairou         9.780367
#      Nongzhanguan   20.606638
#      Shunyi         21.213630
#      Tiantan        14.051554
#      Wanliu         20.325918
#      Wanshouxigong  18.565325

# %% [markdown]
# ## Visualization & Explanatory Analysis

# %% [markdown]
# ### Pertanyaan 1: Bagaimana perbandingan tingkat polutan total antar stasiun?

# %%
# Mendifinikan variabel
pollutants = ['SO2', 'NO2', 'O3', 'PM2.5', 'PM10', 'CO']
stations = ['Dongsi', 'Guanyuan', 'Gucheng', 'Huairou', 'Nongzhanguan', 'Shunyi', 'Tiantan', 'Wanliu', 'Wanshouxigong']

# Groupby 'station' dan hitung rata-rata untuk setiap polutan
grouped = all_df.groupby('station')[pollutants].mean()

# Mengurutkan data berdasarkan total polutan
grouped['total'] = grouped.sum(axis=1)
grouped = grouped.sort_values('total', ascending=False)

# Plotting
fig, ax = plt.subplots(figsize=(10, 7))

# Plot gabungan dengan urutan station dari yang terbesar
grouped[pollutants].plot(kind='barh', stacked=True, ax=ax, title='Perbandingan Tingkat Polutan Total Antar Station')
ax.set_xlabel('Konsentrasi')
ax.invert_yaxis()  # Membalik urutan station

plt.tight_layout()
plt.show()

# %% [markdown]
# Explanatory Analysis:
# * Metode analisis yang digunakan di sini adalah analisis deskriptif, karena grafik ini memberikan gambaran umum tentang tingkat polutan di setiap stasiun.
# * Stasiun Wanshouxigong memiliki tingkat polutan total jauh lebih tinggi dibandingkan stasiun lain
# * Stasiun Dingling memiliki tingkat polutan yang paling rendah dibandingkan stasiun lain
# * Polutan Karbon Monoksida (CO) memiliki konsentrasi yang paling tinggi
# * Polutan Sulfur Dioksida (SO2) memiliki konsentrasi yang paling rendah

# %% [markdown]
# ### Pertanyaan 2: Bagaimana perbandingan tiap polutan pada tiap stasiun?

# %% [markdown]
# Metode analisis yang digunakan di sini adalah analisis deskriptif, karena grafik ini memberikan gambaran umum tentang tingkat tiap polutan di setiap stasiun.

# %% [markdown]
# #### Polutan SO2 (Sulfur Dioksida)

# %%
# Plot untuk SO2
fig, ax = plt.subplots(figsize=(10, 7))
grouped['SO2'].sort_values(ascending=False).plot(kind='bar', color='b', ax=ax, title='Perbandingan Tingkat SO2 Antar Station')
ax.set_ylim([0, grouped['SO2'].max() * 1.1])  # Meningkatkan tinggi sumbu y
ax.set_ylabel('Konsentrasi')
for p in ax.patches:
    ax.annotate(np.round(p.get_height(),decimals=2), (p.get_x()+p.get_width()/2., p.get_height()), ha='center', va='center', xytext=(0, 10), textcoords='offset points')
plt.tight_layout()
plt.show()

# %% [markdown]
# Explanatory Analysis:
# * Konsentrasi polutan Sulfur Dioksida paling tinggi berada pada stasiun Nongzhanguan
# * Konsentrasi polutan Sulfur Dioksida paling rendah berada pada stasiun Dingling

# %% [markdown]
# #### Polutan NO2 (Nitrogen Dioksida)

# %%
# Plot untuk NO2
fig, ax = plt.subplots(figsize=(10, 7))
grouped['NO2'].sort_values(ascending=False).plot(kind='bar', color='g', ax=ax, title='Perbandingan Tingkat NO2 Antar Station')
ax.set_ylim([0, grouped['NO2'].max() * 1.1])  # Meningkatkan tinggi sumbu y
ax.set_ylabel('Konsentrasi')
for p in ax.patches:
    ax.annotate(np.round(p.get_height(),decimals=2), (p.get_x()+p.get_width()/2., p.get_height()), ha='center', va='center', xytext=(0, 10), textcoords='offset points')
plt.tight_layout()
plt.show()

# %% [markdown]
# Explanatory Analysis:
# * Konsentrasi polutan Nitrogen Dioksida paling tinggi berada pada stasiun Wanliu
# * Konsentrasi polutan Nitrogen Dioksida paling rendah berada pada stasiun Dingling

# %% [markdown]
# #### Polutan O3 (Ozon)

# %%
# Plot untuk O3
fig, ax = plt.subplots(figsize=(10, 7))
grouped['O3'].sort_values(ascending=False).plot(kind='bar', color='r', ax=ax, title='Perbandingan Tingkat O3 Antar Station')
ax.set_ylim([0, grouped['O3'].max() * 1.1])  # Meningkatkan tinggi sumbu y
ax.set_ylabel('Konsentrasi')
for p in ax.patches:
    ax.annotate(np.round(p.get_height(),decimals=2), (p.get_x()+p.get_width()/2., p.get_height()), ha='center', va='center', xytext=(0, 10), textcoords='offset points')
plt.tight_layout()
plt.show()

# %% [markdown]
# Explanatory Analysis:
#
# * Konsentrasi polutan Ozon paling tinggi berada pada stasiun Dingling
# * Konsentrasi polutan Nitrogen Dioksida paling rendah berada pada stasiun Wanliu

# %% [markdown]
# #### Polutan PM2.5 (Partikulat 2.5μm)

# %%
# Plot untuk PM2.5
fig, ax = plt.subplots(figsize=(10, 7))
grouped['PM2.5'].sort_values(ascending=False).plot(kind='bar', color='c', ax=ax, title='Perbandingan Tingkat PM2.5 Antar Station')
ax.set_ylim([0, grouped['PM2.5'].max() * 1.1])  # Meningkatkan tinggi sumbu y
ax.set_ylabel('Konsentrasi')
for p in ax.patches:
    ax.annotate(np.round(p.get_height(),decimals=2), (p.get_x()+p.get_width()/2., p.get_height()), ha='center', va='center', xytext=(0, 10), textcoords='offset points')
plt.tight_layout()
plt.show()

# %% [markdown]
# Explanatory Analysis:
#
# * Konsentrasi polutan Partikulat 2.5μm paling tinggi berada pada stasiun Dongsi
# * Konsentrasi polutan Partikulat 2.5μm paling rendah berada pada stasiun Dingling

# %% [markdown]
# #### Polutan PM10 (Partikulat 10μm)

# %%
# Plot untuk PM10
fig, ax = plt.subplots(figsize=(10, 7))
grouped['PM10'].sort_values(ascending=False).plot(kind='bar', color='m', ax=ax, title='Perbandingan Tingkat PM10 Antar Station')
ax.set_ylim([0, grouped['PM10'].max() * 1.1])  # Meningkatkan tinggi sumbu y
ax.set_ylabel('Konsentrasi')
for p in ax.patches:
    ax.annotate(np.round(p.get_height(),decimals=2), (p.get_x()+p.get_width()/2., p.get_height()), ha='center', va='center', xytext=(0, 10), textcoords='offset points')
plt.tight_layout()
plt.show()

# %% [markdown]
# Explanatory Analysis:
#
# * Konsentrasi polutan Partikulat 10μm paling tinggi berada pada stasiun Gucheng
# * Konsentrasi polutan Partikulat 10μm paling rendah berada pada stasiun Dingling

# %% [markdown]
# #### Polutan CO (Karbon Monoksida)

# %%
# Plot untuk CO
fig, ax = plt.subplots(figsize=(10, 7))
grouped['CO'].sort_values(ascending=False).plot(kind='bar', color='y', ax=ax, title='Perbandingan Tingkat CO Antar Station')
ax.set_ylim([0, grouped['CO'].max() * 1.1])  # Meningkatkan tinggi sumbu y
ax.set_ylabel('Konsentrasi')
for p in ax.patches:
    ax.annotate(np.round(p.get_height(),decimals=2), (p.get_x()+p.get_width()/2., p.get_height()), ha='center', va='center', xytext=(0, 10), textcoords='offset points')
plt.tight_layout()
plt.show()

# %% [markdown]
# Explanatory Analysis:
#
# * Konsentrasi polutan Karbon Monoksida paling tinggi berada pada stasiun Wanshouxigong
# * Konsentrasi polutan Karbon Monoksida paling rendah berada pada stasiun Dingling

# %% [markdown]
# ### Pertanyaan 3: Bagaimana pengaruh kondisi lingkungan terhadap tingkat polutan?

# %% [markdown]
# #### Pengaruh curah hujan terhadap kadar CO (Karbon Monoksida)

# %%
plt.figure(figsize=(10, 6))
sns.scatterplot(data=all_df, x='RAIN', y='CO', hue='station')
plt.title('Scatter plot of CO vs RAIN for each station')
plt.show()

# %% [markdown]
# Explanatory Analysis:
# * Metode analisis yang digunakan di sini adalah metode korelasi untuk mengetahui sejauh mana hubungan antara dua variabel. Dalam hal ini kita menghitung koefisien korelasi antara RAIN dan CO untuk setiap stasiun.
# * Titik-titik data cenderung berkumpul di bagian bawah grafik, menunjukkan bahwa kadar CO lebih tinggi ketika curah hujan rendah.

# %% [markdown]
# #### Pengaruh temperatur terhadap kadar O3 (Ozon)

# %%
plt.figure(figsize=(10, 6))
sns.scatterplot(data=all_df, x='TEMP', y='O3', hue='station')
plt.title('Scatter plot of O3 vs TEMP for each station')
plt.show()

# %% [markdown]
# Explanatory Analysis:
# * Metode analisis yang digunakan di sini sama seperti sebelumnya yaitu metode korelasi untuk mengetahui sejauh mana hubungan antara dua variabel. Dalam hal ini kita menghitung koefisien korelasi antara RAIN dan CO untuk setiap stasiun.
# * Dari plot ini, kita bisa melihat bahwa seiring dengan peningkatan suhu, konsentrasi ozon juga cenderung meningkat, meskipun ada beberapa variasi tergantung pada stasiun pengukuran.

# %% [markdown]
# ### Pertanyaan 4: Bagaimana fluktuasi tingkat polutan sepanjang waktu?

# %% [markdown]
# Metode analisis yang digunakan di sini adalah metode time series untuk menganalisis tren dan pola musiman dalam tingkat polutan di setiap stasiun.

# %% [markdown]
# #### Fluktuasi Karbon Monoksida sepanjang waktu

# %%
plt.figure(figsize=(10, 6))

# Buat line chart untuk CO
all_df.groupby('year')['CO'].mean().plot(label='CO')

plt.title('Fluctuation of CO over years')
plt.xlabel('Year')
plt.ylabel('CO concentration')
plt.legend()
plt.show()

# %% [markdown]
# Explanatory Analysis:
# * Dari tahun 2013 hingga sekitar pertengahan 2016, konsentrasi CO relatif stabil dengan sedikit penurunan.
# * Setelah pertengahan 2016, terjadi peningkatan tajam dalam konsentrasi CO.

# %% [markdown]
# #### Fluktuasi polutan lain sepanjang waktu

# %%
# Daftar variabel polutan kecuali CO
pollutants = ['PM2.5', 'PM10', 'SO2', 'NO2', 'O3']

plt.figure(figsize=(10, 6))

# Buat line chart untuk setiap polutan
for pollutant in pollutants:
    all_df.groupby('year')[pollutant].mean().plot(label=pollutant)

plt.title('Fluctuation of pollutants over years')
plt.xlabel('Year')
plt.ylabel('Pollutants concentration')
plt.legend()
plt.show()

# %% [markdown]
# Explanatory Analysis:
# * Seluruh polutan kecuali Ozon (O3) mengalami sedikit penurunan pada tahun 2014 sampai 2016 hingga akhirnya nilainya meningkat kembali pada pertengahan tahub 2016 sampai tahun 2017
# * Konsentrasi ozon cenderung stabil pada tahun 2013 sampai 2016 dengan penurunan pada tahun 2016 hingga 2017

# %% [markdown]
# ### Pertanyaan 5: Bagaimana distribusi stasiun berdasarkan tingkat polutan dan kondisi lingkungan? (Cluster)

# %% [markdown]
# Metode analisis yang digunakan di sini adalah metode kluster untuk mengelompokkan stasiun berdasarkan tingkat polutan mereka, Anda dapat menggunakan teknik klastering. Metode ini akan mengidentifikasi stasiun yang memiliki tingkat polutan yang serupa.

# %%
all_df = pd.get_dummies(all_df, columns=['wd'])

# %%
# Pilih fitur yang akan digunakan untuk clustering
features = ['PM2.5', 'PM10', 'SO2', 'NO2', 'CO', 'O3', 'TEMP', 'PRES', 'DEWP', 'RAIN', 'WSPM',
            'wd_E', 'wd_ENE', 'wd_ESE', 'wd_N', 'wd_NE', 'wd_NNE', 'wd_NNW', 'wd_NW', 'wd_S',
            'wd_SE', 'wd_SSE', 'wd_SSW', 'wd_SW', 'wd_W', 'wd_WNW', 'wd_WSW']
X = all_df[features]

# Normalisasi data
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# Tentukan jumlah cluster
n_clusters = 3

# Lakukan clustering
kmeans = KMeans(n_clusters=n_clusters, random_state=0)
all_df['cluster'] = kmeans.fit_predict(X_scaled)

# Cetak hasil clustering
for i in range(n_clusters):
    print(f"Cluster {i}:")
    print(all_df[all_df['cluster'] == i])
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# Cluster 0:
#            No  year  month  day  hour  PM2.5  PM10   SO2   NO2     CO  ...  \
# 0           1  2013      3    1     0    4.0   4.0   4.0   7.0  300.0  ...
# 1           2  2013      3    1     1    8.0   8.0   4.0   7.0  300.0  ...
# 2           3  2013      3    1     2    7.0   7.0   5.0  10.0  300.0  ...
# 3           4  2013      3    1     3    6.0   6.0  11.0  11.0  300.0  ...
# 4           5  2013      3    1     4    3.0   3.0  12.0  12.0  300.0  ...
# ...       ...   ...    ...  ...   ...    ...   ...   ...   ...    ...  ...
# 420763  35060  2017      2   28    19   11.0  32.0   3.0  24.0  400.0  ...
# 420764  35061  2017      2   28    20   13.0  32.0   3.0  41.0  500.0  ...
# 420765  35062  2017      2   28    21   14.0  28.0   4.0  38.0  500.0  ...
# 420766  35063  2017      2   28    22   12.0  23.0   4.0  30.0  400.0  ...
# 420767  35064  2017      2   28    23   13.0  19.0   4.0  38.0  600.0  ...
#
#         wd_NW   wd_S  wd_SE  wd_SSE  wd_SSW  wd_SW   wd_W  wd_WNW  wd_WSW  \
# 0       False  False  False   False   False  False  False   False   False
# 1       False  False  False   False   False  False  False   False   False
# 2       False  False  False   False   False  False  False   False   False
# 3        True  False  False   False   False  False  False   False   False
# 4       False  False  False   False   False  False  False   False   False
# ...       ...    ...    ...     ...     ...    ...    ...     ...     ...
# 420763   True  False  False   False   False  False  False   False   False
# 420764  False  False  False   False   False  False  False    True   False
# 420765   True  False  False   False   False  False  False   False   False
# 420766  False  False  False   False   False  False  False   False   False
# 420767  False  False  False   False   False  False  False   False   False
#
#         cluster
# 0             0
# 1             0
# 2             0
# 3             0
# 4             0
# ...         ...
# 420763        0
# 420764        0
# 420765        0
# 420766        0
# 420767        0
#
# [139758 rows x 34 columns]
# Cluster 1:
#            No  year  month  day  hour  PM2.5   PM10   SO2    NO2      CO  ...  \
# 180       181  2013      3    8    12  104.0  194.0  37.0  101.0  1399.0  ...
# 181       182  2013      3    8    13  121.0  225.0  40.0   96.0  1300.0  ...
# 186       187  2013      3    8    18   82.0  128.0  55.0   63.0   900.0  ...
# 187       188  2013      3    8    19   84.0  123.0  46.0   73.0  1100.0  ...
# 188       189  2013      3    8    20   91.0  104.0  48.0   65.0  1000.0  ...
# ...       ...   ...    ...  ...   ...    ...    ...   ...    ...     ...  ...
# 418120  32417  2016     11   10    16  176.0  190.0   8.0   63.0  1300.0  ...
# 418166  32463  2016     11   12    14   84.0  143.0  20.0   67.0  1600.0  ...
# 418167  32464  2016     11   12    15   81.0  138.0  17.0   57.0  1400.0  ...
# 418168  32465  2016     11   12    16   86.0  138.0  14.0   70.0  1400.0  ...
# 418169  32466  2016     11   12    17   90.0  156.0   9.0   76.0  1400.0  ...
#
#         wd_NW   wd_S  wd_SE  wd_SSE  wd_SSW  wd_SW   wd_W  wd_WNW  wd_WSW  \
# 180     False   True  False   False   False  False  False   False   False
# 181     False   True  False   False   False  False  False   False   False
# 186     False   True  False   False   False  False  False   False   False
# 187     False  False  False   False   False  False  False   False   False
# 188     False  False  False   False    True  False  False   False   False
# ...       ...    ...    ...     ...     ...    ...    ...     ...     ...
# 418120  False  False  False   False   False   True  False   False   False
# 418166  False   True  False   False   False  False  False   False   False
# 418167  False  False  False    True   False  False  False   False   False
# 418168  False  False  False    True   False  False  False   False   False
# 418169  False   True  False   False   False  False  False   False   False
#
#         cluster
# 180           1
# 181           1
# 186           1
# 187           1
# 188           1
# ...         ...
# 418120        1
# 418166        1
# 418167        1
# 418168        1
# 418169        1
#
# [197124 rows x 34 columns]
# Cluster 2:
#            No  year  month  day  hour  PM2.5   PM10    SO2    NO2      CO  \
# 43         44  2013      3    2    19   61.0   86.0  50.00   97.0  1300.0
# 44         45  2013      3    2    20   67.0   96.0  54.00  108.0  1399.0
# 45         46  2013      3    2    21   74.0  103.0  72.00  107.0  1399.0
# 46         47  2013      3    2    22   81.0  113.0  84.00  110.0  1500.0
# 47         48  2013      3    2    23   93.0  120.0  87.00  107.0  1700.0
# ...       ...   ...    ...  ...   ...    ...    ...    ...    ...     ...
# 420730  35027  2017      2   27    10  103.0  127.0  32.00   78.0  1800.0
# 420731  35028  2017      2   27    11  104.5  122.5  29.75   84.5  1800.0
# 420732  35029  2017      2   27    12  106.0  118.0  27.50   91.0  1800.0
# 420733  35030  2017      2   27    13  107.5  113.5  25.25   97.5  1800.0
# 420734  35031  2017      2   27    14  109.0  109.0  23.00  104.0  1800.0
#
#         ...  wd_NW   wd_S  wd_SE  wd_SSE  wd_SSW  wd_SW   wd_W  wd_WNW  \
# 43      ...  False  False  False   False   False  False  False   False
# 44      ...  False  False  False   False   False  False  False   False
# 45      ...  False  False  False   False   False  False  False   False
# 46      ...  False  False  False   False   False  False  False   False
# 47      ...  False  False  False   False   False  False  False   False
# ...     ...    ...    ...    ...     ...     ...    ...    ...     ...
# 420730  ...  False  False  False   False   False  False  False   False
# 420731  ...  False  False  False   False   False  False  False   False
# 420732  ...  False  False  False   False    True  False  False   False
# 420733  ...  False  False  False    True   False  False  False   False
# 420734  ...  False  False  False   False   False   True  False   False
#
#         wd_WSW  cluster
# 43       False        2
# 44       False        2
# 45       False        2
# 46       False        2
# 47       False        2
# ...        ...      ...
# 420730   False        2
# 420731   False        2
# 420732   False        2
# 420733   False        2
# 420734   False        2
#
# [83886 rows x 34 columns]

# %% [markdown]
# Dengan kode di atas, sekarang kita memiliki kolom 'cluster' dalam DataFrame yang menunjukkan cluster mana setiap stasiun termasuk berdasarkan tingkat polutan dan kondisi lingkungan. Scatter plot menunjukkan distribusi stasiun berdasarkan tingkat PM2.5 dan PM10, dengan warna yang menunjukkan cluster.

# %%
# Visualisasi hasil clustering
plt.figure(figsize=(10, 7))
sns.scatterplot(data=all_df, x='PM2.5', y='PM10', hue='cluster', palette='viridis')
plt.title('Hasil Clustering')
plt.xlabel('PM2.5')
plt.ylabel('PM10')
plt.show()

# %% [markdown]
# Explanatory Analysis:
# * Cluster 2 (Kuning): Stasiun dalam cluster ini memiliki tingkat PM2.5 dan PM10 yang relatif rendah. Hal ini menunjukkan bahwa stasiun-stasiun ini berada di area dengan kualitas udara yang lebih baik atau kurang terpengaruh oleh sumber polusi.
# * Cluster 0 (Ungu): Stasiun dalam cluster ini memiliki tingkat PM2.5 yang rendah hingga menengah dan tingkat PM10 yang menengah. Hal ini menunjukkan bahwa stasiun-stasiun ini berada di area yang memiliki beberapa sumber polusi, tetapi tidak sebanyak stasiun dalam cluster 2.
# * Cluster 1 (Hijau): Stasiun dalam cluster ini memiliki tingkat PM2.5 dan PM10 yang relatif tinggi. Hal ini menunjukkan bahwa stasiun-stasiun ini berada di area dengan banyak sumber polusi atau kondisi yang mengarah pada penumpukan polutan.

# %% [markdown]
# ## Conclusion

# %% [markdown]
# - Conclution pertanyaan 1 (Bagaimana perbandingan tingkat polutan total antar stasiun?) **Jawab:**
# Stasiun Wanshouxigong memiliki tingkat polutan total jauh lebih tinggi dibandingkan stasiun lain, sedangkan Dingling memiliki tingkat polutan yang paling rendah.
# - Conclution pertanyaan 2 (Bagaimana perbandingan tiap polutan pada tiap stasiun?) **Jawab:** Stasiun Dingling cenderung memiliki konsentrasi rendah pada tiap polutan dibadingkan stasiun lain.
# - Conclution pertanyaan 3 (Bagaimana pengaruh kondisi lingkungan terhadap tingkat polutan?) **Jawab:** Kondisi lingkungan seperti curah hujan dan temperatur mempengaruhi konsentrasi polutan.
# - Conclution pertanyaan 4 (Bagaimana fluktuasi tingkat polutan sepanjang waktu?) **Jawab:** Hampir seluruh polutan mengalami fluktuasi sepanjang waktu kecuali O3 atau ozon.
# - Conclution pertanyaan 5 (Bagaimana distribusi stasiun berdasarkan tingkat polutan dan kondisi lingkungan? (Cluster)) **Jawab:** Stasiun yang berkategori cluster 1 menunjukkan konsentrasi polutan paling tinggi dibandingkan stasiun cluster lainnya.

# %% [markdown]
# Menyimpan berkas data yang telah dibersihkan

# %%
all_df.to_csv("all_data.csv", index=False)
